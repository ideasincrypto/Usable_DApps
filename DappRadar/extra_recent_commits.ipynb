# %%
import pandas as pd
import requests
import json
import time
import os
from datetime import datetime as DT

# %%
df = pd.read_csv("./3rd_stage_git_owners.csv")
df.head()
# Out:
#    Unnamed: 0           Name  \
# 0           0    PancakeSwap
# 1           1   AtomicAssets
# 2           2   AtomicMarket
# 3           3  Axie Infinity
# 4           4  X World Games
#
#                                                 Link  \
# 0  https://dappradar.com/binance-smart-chain/defi...
# 1  https://dappradar.com/multichain/other/atomica...
# 2  https://dappradar.com/multichain/marketplaces/...
# 3  https://dappradar.com/multichain/games/axie-in...
# 4  https://dappradar.com/binance-smart-chain/game...
#
#                                               Github         Owner  \
# 0                     https://github.com/pancakeswap   pancakeswap
# 1  https://github.com/pinknetworkx/atomicassets-c...  pinknetworkx
# 2                    https://github.com/pinknetworkx  pinknetworkx
# 3                https://freakitties.github.io/axie/          axie
# 4                     https://github.com/XWorldGames   XWorldGames
#
#        Category           Blockchain
# ...

# %%
username = "abhilashdzr"
token = "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"
gh_session = requests.Session()
gh_session.auth = (username, token)

# %%
df2 = pd.read_csv("./contributors_recent_projects/recent_projects.csv")
cur_date = DT.now()

common_url = "https://api.github.com"

for ind,row in df.iterrows(): 
    
    ownerjson = {}
    set_contributors = set()

    owner = row["Owner"]
    print(owner)


    if owner in df2["Name"].tolist():
        continue 

    ownerjson["id"] = owner

    url = common_url + f'/users/{owner}/repos'
    
    page = 1
    another_page = True
    repo_list = []
    try:
        while another_page:
            gh_session.params = {'page':page, 'per-page':100}
            r = gh_session.get(url)
            # print(r.text)
            json_response = json.loads(r.text)
            for each in json_response:
                repo_list.append(each["name"])
            if 'next' in r.links:
                page +=1
                time.sleep(1)
            else:
                page = 1
                another_page = False
                
    except:
        pass
    # time.sleep(1)

    url2 = common_url + f'/users/{owner}'

    try:
        ownerjson["location"] = gh_session.get(url2).json()["location"]
    except:
        pass

    
    print(repo_list)
    # print(repo_json)

    recent_commit_date = DT(1970,1,1)

    time.sleep(2)

    for repo in repo_list:
        # print(repo)
        try:
            time.sleep(1)
            url_commit = "https://api.github.com/repos/" + owner + "/" + repo + "/commits"
            # print(url_commit)
            # content = gh_session.get(url_commit).json()
            content = requests.get(url_commit,auth=(username,token)).json()

            try:
                recent_most_date = content[0]["commit"]["author"]["date"]
                # print(recent_most_date)
            except:
                continue 


            yy = recent_most_date[:10][:4]
            mm = recent_most_date[:10][5:7]
            dd = recent_most_date[:10][8:10]


            x = DT(int(yy),int(mm),int(dd))
            recent_commit_date = max(recent_commit_date,x)
            
        except:
            continue
    
    print(recent_commit_date)
    diff_time = cur_date - recent_commit_date
    total_months = diff_time.total_seconds()/2.628e+6
    print(owner,total_months)
    if(total_months>6):
        continue

    df3 = pd.DataFrame({"Name":[owner],"Last Date":[recent_commit_date]})
    df2 = df2.append(df3,ignore_index=True)
    df2.to_csv("./contributors_recent_projects/recent_projects.csv")

    if ind%5==0:
        time.sleep(10)
# Out:
# pancakeswap
# ['eslint-config-pancake', 'gatsby-pancake-api', 'initial-farm-offering', 'lottery-contract', 'pancake-document', 'pancake-farm', 'pancake-frontend', 'pancake-info-api', 'pancake-info-v1', 'pancake-lottery-scheduler', 'pancake-nft-api', 'pancake-nft-publish', 'pancake-profile-api', 'pancake-smart-contracts', 'pancake-subgraph', 'pancake-swap-core', 'pancake-swap-interface-v1', 'pancake-swap-lib', 'pancake-swap-periphery', 'pancake-swap-sdk', 'pancake-toolkit', 'pancake-uikit', 'pancake-v2-subgraph', 'PancakeSwap-Design', 'Revelation-Hackathon-Bounties', 'snapshot', 'snapshot-spaces', 'snapshot.js', 'swap-orders-lib', 'token-list', 'token-pocket-splash']
# 2022-09-12 00:00:00
# pancakeswap 0.027388181684550986
# pinknetworkx
# ...
