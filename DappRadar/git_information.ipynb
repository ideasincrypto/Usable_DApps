# %%
import pandas as pd
import requests
import json
import time
import os

# %%
df = pd.read_csv("./3rd_stage_git_owners.csv")
df.head()
# Out:
#    Unnamed: 0           Name  \
# 0           0    PancakeSwap
# 1           1   AtomicAssets
# 2           2   AtomicMarket
# 3           3  Axie Infinity
# 4           4  X World Games
#
#                                                 Link  \
# 0  https://dappradar.com/binance-smart-chain/defi...
# 1  https://dappradar.com/multichain/other/atomica...
# 2  https://dappradar.com/multichain/marketplaces/...
# 3  https://dappradar.com/multichain/games/axie-in...
# 4  https://dappradar.com/binance-smart-chain/game...
#
#                                               Github         Owner  \
# 0                     https://github.com/pancakeswap   pancakeswap
# 1  https://github.com/pinknetworkx/atomicassets-c...  pinknetworkx
# 2                    https://github.com/pinknetworkx  pinknetworkx
# 3                https://freakitties.github.io/axie/          axie
# 4                     https://github.com/XWorldGames   XWorldGames
#
#        Category           Blockchain
# ...

# %%
username = "abhilashdzr"
token = "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"
gh_session = requests.Session()
gh_session.auth = (username, token)

# %%
common_url = "https://api.github.com"

for ind,row in df.iterrows():
    
    ownerjson = {}
    set_contributors = set()

    owner = row["Owner"]

    path = f"/home/abhilash/Desktop/August_scraping/DappRadar/contributors/{owner}.json"
    if os.path.exists(path):
        continue
    
    print(row['Owner'])

    ownerjson["id"] = owner

    url = common_url + f'/users/{owner}/repos'
    
    page = 1
    another_page = True
    repo_list = []
    try:
        while another_page:
            gh_session.params = {'page':page, 'per-page':100}
            r = gh_session.get(url)
            # print(r.text)
            json_response = json.loads(r.text)
            for each in json_response:
                repo_list.append(each["name"])
            if 'next' in r.links:
                page +=1
                time.sleep(1)
            else:
                page = 1
                another_page = False
                
    except:
        pass
    # time.sleep(1)

    url2 = common_url + f'/users/{owner}'

    try:
        ownerjson["location"] = gh_session.get(url2).json()["location"]
    except:
        pass
    
    print(repo_list)
    # print(repo_json)
    for repo in repo_list:
        try:
            contributor_url = common_url + f'/repos/{owner}/{repo}/stats/contributors'
            contributors = gh_session.get(contributor_url).json()

            for c in contributors:
                id = c["author"]["login"]

                contributor_url = common_url + f'/users/{id}'
                this_contributor = gh_session.get(contributor_url).json()
                time.sleep(.5)

                set_contributors.add((id, this_contributor["location"]))
            
        except:
            continue


    ownerjson["contributors"] = list(set_contributors)

    json_object = json.dumps(ownerjson, indent = 4)
    f = open(f"./contributors/{owner}.json", "x")
    f.write(json_object)
    f.close()
    # print(json_object)


    # time.sleep(5)
    # if ind%5==0:
    #     time.sleep(10)
# Out:
# AlkemiNetwork
# ['alkemi-assets', 'alkemi-content', 'alkemi-earn-contracts', 'alkemi-earn-kyc-service', 'alkemi-earn-protocol-v2', 'alkemi-earn-safe-app', 'alkemi-earn-security-audit', 'alkemi-ledger-app', 'alkemi-ledger-plugin', 'alkemi-reserve-contracts', 'alkemi-reserve-ui', 'alkemi-tokens-contracts', 'alkemi-ui-template', 'api-docs', 'projects']
# AlpacaCity
# ['AlpacaCity', 'cn-blog', 'github-pages', 'token-profile']
# BarnBridge
# ...
