# %%
import pandas as pd
import os

# %%
pwd
# Out:
# '/home/abhilash/Desktop/August_scraping/merged'

# %%
all_json_name_list = os.listdir("./contributors/")
# print(all_json_name_list)
print(len(all_json_name_list))
# Out:
# 580

# %%
#all contributor list
all_contributors = []

#to mark each contributor
contributor_id = {}

#project id 
project_id = {}

#map contributor ctr's to that project
contributor_map = {}

json_ctr = 0  
contributor_ctr = 0
project_ctr = 0

for name in all_json_name_list:
  try:
    df = pd.read_json("./contributors/"+name)
  except:
    continue

  if len(df["contributors"])==0:
    continue

  project_ctr+=1 
  print(name)
  project_id[df["id"][0]] = project_ctr

  #initialize a set to each project contributor map
  contributor_map[project_ctr] = set()

  for contributor in df["contributors"]:
    if contributor[0] not in all_contributors:
      contributor_ctr+=1
      all_contributors.append(contributor[0])
      contributor_id[contributor[0]] = contributor_ctr
    contributor_map[project_ctr].add(contributor_id[contributor[0]])

  # if(project_ctr==20):
  #     break

f = open("./louvain/graph_in_figures.txt",'w')

for i in range(1,project_ctr):
  for j in range(i+1,project_ctr+1):
    s1 = contributor_map[i]
    s2 = contributor_map[j]
    s_intersection = s1 & s2
    # print(i," ",j," ",len(s_intersection))
    f.write(str(i)+" "+str(j)+" "+str(len(s_intersection)))
    f.write("\n")

f.close()

#contributor list ---> name --> id
df2 = pd.DataFrame(contributor_id.items(),columns=["contributor name", "contributor id"])
df2.to_csv("./louvain/contributor_id_mapping.csv")

#project list --> name of project --> id
df3 = pd.DataFrame(project_id.items(),columns=["project name", "project id"])
df3.to_csv("./louvain/project_id_mapping.csv")
# Out:
# peckshield.json
# perifinance.json
# arenaswap.json
# cykura.json
# wigoswap.json
# ZunamiLab.json
# holgern.json
# trustdomains.json
# RequestNetwork.json
# sudoswap.json
# VenusProtocol.json
# celo-tools.json
# triplefi.json
# ProjectOpenSea.json
# ArrakisFinance.json
# notional-finance.json
# Bombmoney.json
# burgerswap-org.json
# Llamafinance.json
# justliquidity.json
# NexusMutual.json
# balancer-labs.json
# metavaultorg.json
# candlegenie.json
# BenTokenFinance.json
# traderjoe-xyz.json
# sil-finance.json
# Idle-Labs.json
# liquity.json
# InterCroneworldOrg.json
# GimmerBot.json
# mean-dao.json
# sishi-finance.json
# DODOEX.json
# risqprotocol.json
# across-protocol.json
# 0xProject.json
# bifrost-platform.json
# Multiven-Group-BV.json
# KlimaDAO.json
# Crypto-Shots.json
# CurioTeam.json
# openocean-finance.json
# NFTBlackMarket.json
# PositionExchange.json
# zenlinkpro.json
# AlgoNetwork.json
# dfyn.json
# shipyard-software.json
# FATEx-DAO.json
# d1ggy1bh.json
# tokencard.json
# liquidapps-io.json
# harvest-finance.json
# latteswap-official.json
# cronaswap.json
# Switcheo.json
# Polkamarkets.json
# chocomintapp.json
# status-im.json
# oneswap.json
# cVault-finance.json
# tonlabs.json
# ArthSwap.json
# VikingDefi.json
# copuppy.json
# autoshark-finance.json
# celer-network.json
# apeswapfinance.json
# muuu-finance.json
# polydex-fi.json
# MagicBallSwap.json
# zoomswap.json
# peakdefi.json
# scv-finance.json
# cbdcash.json
# mstable.json
# MillionOnMars.json
# golfffinance.json
# moneyTulip.json
# Singularitysgly.json
# Bitcratic.json
# GoldPesa.json
# pancakeswap.json
# ChikinDeveloper.json
# CryptoLions.json
# bender-labs.json
# swashapp.json
# polycatfi.json
# symbiosis-finance.json
# ethalend.json
# XYOracleNetwork.json
# amptoken.json
# dluxio.json
# bondappetit.json
# 0xbitcoin.json
# inthenextversion.json
# sushiswap.json
# BendDAO.json
# samuskyio.json
# meterio.json
# cryptocookiesdao.json
# fei-protocol.json
# tofudefi.json
# hop-protocol.json
# larvalabs.json
# babyswap.json
# fuseio.json
# cexiswap.json
# numerai.json
# bancorprotocol.json
# TemplarDAO.json
# COGI-Technology.json
# br34p.json
# NestedFi.json
# darcius.json
# minds.json
# dragonereum.json
# uniclyNFT.json
# Xpool-lab.json
# Timikcool.json
# alchemix-finance.json
# MysteriumNetwork.json
# Smartlinkhub.json
# omgnetwork.json
# LunchMoneyToken.json
# district0x.json
# Night-Life-Crypto.json
# kwikswap.json
# ringfi.json
# rottenswap.json
# farmersonlydefi.json
# singnet.json
# friendsfingers.json
# primasio.json
# router-protocol.json
# StakeDAO.json
# dante-finance.json
# BarbershopFinance.json
# versa-finance-dev.json
# spankchain.json
# worldbetdev.json
# dovuofficial.json
# TheMinders.json
# NEARCrowd.json
# octofi.json
# InverseFinance.json
# OpenLeverageDev.json
# OtterClam.json
# niobfinance.json
# ZeroSwapLabs.json
# buffaloswap.json
# levelkdev.json
# tranquil-finance.json
# pitbullBSC.json
# lifinance.json
# KingLuigy.json
# VeriSafe.json
# lockfinance.json
# tokenjenny.json
# acorn-finance.json
# GenesisVision.json
# plotx.json
# Aircoin-official.json
# saddle-finance.json
# originprotocol.json
# renproject.json
# swaap-labs.json
# RAMP-DEFI.json
# magiclandfinance.json
# f-o-a-m.json
# HoneyFarmFi.json
# Gangster-Protocol.json
# peppersec.json
# carv-protocol.json
# Neopin.json
# BullRunFinance.json
# O3Labs.json
# curvefi.json
# tenfinance.json
# swamp-finance.json
# CycleProtocol.json
# vesperfi.json
# cyclese96.json
# AuraSwap-DEX.json
# flashliquidity.json
# AugurProject.json
# pantherswap.json
# cryptovoxels.json
# iotexproject.json
# CaskProtocol.json
# gravis-finance.json
# ecency.json
# Uniswap.json
# portto.json
# Storj.json
# cometh-game.json
# poanetwork.json
# juster-finance.json
# TuttiFruttiFinance.json
# answerswap.json
# oneverseone.json
# lootex-io.json
# ref-finance.json
# DoppleFinance.json
# polyroll.json
# kalmar-io.json
# becoswap.json
# dexkit.json
# umaprotocol.json
# 0xalmanac.json
# Good-Ghosting.json
# KokomoSwap.json
# omni-corp-protocols.json
# SunContract.json
# alexgo-io.json
# Samurai-Legends.json
# xcarnival.json
# dexira.json
# Convergence-Finance.json
# synthetixio.json
# NEST-Protocol.json
# ustx.json
# RenovJ.json
# VeneraFinance.json
# 888tron.json
# airswap.json
# lnswap.json
# NewBFarm.json
# MakerDAO.json
# likecoin.json
# SwerveFinance.json
# 1inch.json
# xDAO-App.json
# macaronswap.json
# HuckleberryDex.json
# dydxprotocol.json
# Project312.json
# InsurAce-Protocol.json
# winery-land.json
# chimpyswap.json
# InfinityWallet.json
# thetatoken.json
# skyward-finance.json
# enjin.json
# yieldyak.json
# BitBlocksProject.json
# ApeRocket-Labs.json
# apollox-finance.json
# alpaca-finance.json
# boggedfinance.json
# hodltreeprotocol.json
# CryptoDevelopmentServices.json
