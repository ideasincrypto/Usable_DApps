# %%
import pandas as pd
import requests

# %%
df = pd.read_csv("./2nd_stage_scraping.csv")
print(df.head())
# Out:
#    Unnamed: 0                   Name  \
# 0           0                  Oasis
# 1           1  Ethereum Name Service
# 2           2           Decentraland
# 3           3             NEAR Crowd
# 4           4                   Lido
#
#                                                 Link  \
# 0        https://www.stateofthedapps.com/dapps/oasis
# 1  https://www.stateofthedapps.com/dapps/ethereum...
# 2  https://www.stateofthedapps.com/dapps/decentra...
# 3   https://www.stateofthedapps.com/dapps/near-crowd
# 4         https://www.stateofthedapps.com/dapps/lido
#
#                                               Github  Category Blockchain
# 0  https://github.com/MakerDAO?utm_source=StateOf...   Finance   Ethereum
# 1  https://github.com/ensdomains?utm_source=State...  Property   Ethereum
# 2  https://github.com/decentraland?utm_source=Sta...  Property   Ethereum
# 3  https://github.com/NEARCrowd/NEARCrowd?utm_sou...    Social       NEAR
# 4  https://github.com/lidofinance?utm_source=Stat...      DeFi   Ethereum

# %%
df3 = pd.DataFrame(columns=["Name" , "Link" , "Github", "Owner", "Category", "Blockchain"])

for ind,row in df.iterrows():

  link = row["Github"]
  resp = requests.get(link)
  if(resp.status_code!=200):
    continue

  ctr = 0
  pos3 = -1   #3rd occurence of /
  pos4 = -1   #3rd occurence of /

  for i in range(len(link)):
    if link[i]=='/':
      ctr+=1
      if ctr==3:
        pos3 = i 
      if ctr==4:
        pos4= i  
        break  

  if (pos3 == -1 and pos4 == -1) or pos3 == -1: 
    continue  
  
  if pos4 == -1:
    owner = link[pos3+1:]
  else:
    owner = link[pos3+1:pos4]
  
  if "?" in owner:
    mark_pos = owner.find("?")
    owner = owner[:mark_pos]

  print(owner)

  df2 = {"Name": row["Name"], "Link": row["Link"], "Github": link, "Owner": owner, "Category":row["Category"], "Blockchain":row["Blockchain"]}
  df3 = df3.append(df2,ignore_index=True)
  
df3.to_csv("./3rd_stage_git_owners.csv")
# Out:
# MakerDAO
# ensdomains
# decentraland
# NEARCrowd
# lidofinance
# smartcontractkit
# Uniswap
# livepeer
# status-im
# 0xProject
# compound-finance
# Convergence-Finance
# MakerDAO
# ensdomains
# decentraland
# NEARCrowd
# lidofinance
# smartcontractkit
# Uniswap
# livepeer
# status-im
# 0xProject
# compound-finance
# Convergence-Finance
# brave-intl
# ProjectOpenSea
# singnet
# sushiswap
# nexofinance
# oceanprotocol
# omgnetwork
# unstoppabledomains
# originprotocol
# Lescovex
# balancer-labs
# dypfinance
# Kromatika-Finance
# RequestNetwork
# byteball
# bandprotocol
# aave
# Storj
# aleph-im
# quantstamp
# kyberNetwork
# Idle-Labs
# InverseFinance
# Kromatika-Finance
# peakdefi
# symbiosis-finance
# openocean-finance
# polymathnetwork
# airswap
# bancorprotocol
# plasmadlt
# iotexproject
# octofi
# notional-finance
# fuseio
# poanetwork
# byteball
# enjin
# kleros
# selfkeyfoundation
# niobfinance
# peppersec
# Datamine-Crypto
# Samurai-Legends
# golemfactory
# sparkpointio
# darcius
# deversifi
# vesperfi
# cryptovoxels
# InkProtocol
# axieinfinity
# GoldPesa
# Steemhunt
# debridge-finance
# republicprotocol
# gnosis
# howeguo
# DexKit
# hellobloom
# dpdanpittman
# aavegotchi
# f-o-a-m
# byteball
# DigixGlobal
# lordlessio
# warriders
# patrn-me
# chichicoding
# larvalabs
# crypto-com
# XYOracleNetwork
# JoinColony
# CubFinance
# patrn-me
# byteball
# Aircoin-official
# Instadapp
# 2key
# pickle-finance
# tokencard
# etheremon
# aragon
# mstable
# marscolony-io
# spankchain
# Project312
# patrn-me
# StakinOfficial
# minds
# pancakeswap
# ethfinex
# atomex-me
# gelatodigital
# evolutionlandorg
# AugurProject
# 0xbitcoin
# m00nbeans
# martinsawstrom
# DODOEX
# SapienNetwork
# plotx
# Polkamarkets
# SunContract
# Multiven-Group-BV
# gnosis
# district0x
# byteball
# Cryptower
# art101nft
# aelfProject
# LunchMoneyToken
# Yup-io
# BNbitcoin
# CryptoIcarus
# arb-aa-ui
# sablierhq
# canyacoin
# tokenbb-com
# VeriSafe
# nolossclub
# Fiscus-fyi
# Morpher-io
# swashapp
# GenesisVision
# CashCowProject
# district0x
# raiden-network
# ToadNetwork
# portalnetwork
# swarmcity
# melonproject
# AmbireTech
# ZinFinance
# MysteriumNetwork
# numerai
# santiment
# dluxio
# solarbeamio
# GimmerBot
# d1ggy1bh
# dexkit
# zenlinkpro
# likecoin
# bamboo-defi
# risqprotocol
# kardiachain
# HuckleberryDex
# lockfinance
# peppersec
# primasio
# exon-center
# neverlandfinance
# powerdada
# gvandriel
# answerswap
# NEST-Protocol
# dragonereum
# bzxnetwork
# CryptoMinerWorld
# friendsfingers
# CarpeDAO
# dovuofficial
# XinFinOrg
# thetatoken
# mochi-lab
# enigmampc
