# %%
import pandas as pd
import requests
import json
import time
import os

# %%
df = pd.read_csv("./3rd_stage_git_owners.csv")
df.head()
# Out:
#    Unnamed: 0             Name                                  Link  \
# 0           0  Arrakis Finance  https://dapp.com/app/arrakis-finance
# 1           1    Aave Protocol    https://dapp.com/app/aave-protocol
# 2           2   Alpaca Finance   https://dapp.com/app/alpaca-finance
# 3           3   Venus Protocol   https://dapp.com/app/venus-protocol
# 4           4         Compound         https://dapp.com/app/Compound
#
#                                               Github             Owner  \
# 0                  https://github.com/ArrakisFinance    ArrakisFinance
# 1                            https://github.com/aave              aave
# 2                  https://github.com/alpaca-finance    alpaca-finance
# 3    https://github.com/VenusProtocol/Venus-Protocol     VenusProtocol
# 4  https://github.com/compound-finance/compound-p...  compound-finance
#
#   Category Blockchain
# 0  Finance   Ethereum
# 1  Finance   Ethereum
# 2  Finance  BNB Chain
# 3  Finance  BNB Chain
# 4  Finance   Ethereum

# %%
username = "abhilashdzr"
token = "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"
gh_session = requests.Session()
gh_session.auth = (username, token)

# %%
common_url = "https://api.github.com"

for ind,row in df.iterrows():

    ownerjson = {}
    set_contributors = set()

    owner = row["Owner"]

    path = f"/home/abhilash/Desktop/August_scraping/Dapp.com/contributors/{owner}.json"
    if os.path.exists(path):
        continue
    
    print(row['Owner'])

    ownerjson["id"] = owner

    url = common_url + f'/users/{owner}/repos'
    
    page = 1
    another_page = True
    repo_list = []
    try:
        while another_page:
            gh_session.params = {'page':page, 'per-page':100}
            r = gh_session.get(url)
            # print(r.text)
            json_response = json.loads(r.text)
            for each in json_response:
                repo_list.append(each["name"])
            if 'next' in r.links:
                page +=1
                time.sleep(1)
            else:
                page = 1
                another_page = False
                
    except:
        pass
    # time.sleep(1)

    url2 = common_url + f'/users/{owner}'

    try:
        ownerjson["location"] = gh_session.get(url2).json()["location"]
    except:
        pass
    
    print(repo_list)
    # print(repo_json)
    for repo in repo_list:
        try:
            contributor_url = common_url + f'/repos/{owner}/{repo}/stats/contributors'
            contributors = gh_session.get(contributor_url).json()

            for c in contributors:
                id = c["author"]["login"]

                contributor_url = common_url + f'/users/{id}'
                this_contributor = gh_session.get(contributor_url).json()
                time.sleep(.5)

                set_contributors.add((id, this_contributor["location"]))
            
        except:
            continue


    ownerjson["contributors"] = list(set_contributors)

    json_object = json.dumps(ownerjson, indent = 4)
    f = open(f"./contributors/{owner}.json", "x")
    f.write(json_object)
    f.close()

    # time.sleep(5)
    if ind%5==0:
        time.sleep(10)
# Out:
# certusone
# ['aiakos', 'buildscripts', 'chainlink_exporter', 'chain_exporter', 'cosmos-sdk', 'dc4bc', 'explorer', 'game-of-stakes', 'genesis-collector', 'genesisTransactions', 'genki-2000', 'genki-3000', 'genki-3001', 'genki-4000', 'janus', 'kb', 'near_exporter', 'oyster', 'radiance', 'santa', 'solana-go', 'solana_exporter', 'tendermint', 'tendermint-mpc-validator', 'terra-oracle', 'testnets', 'testnet_deploy', 'the-quest-entities', 'tm_exporter', 'ton_cpp_exporter', 'validator-profiles', 'wasmd', 'wormhole', 'wormhole-examples', 'wormhole-icco', 'wormhole-nativeswap-example', 'wormhole-networks', 'wormhole-relayer-list', 'wormhole-token-list', 'xdapp-book', 'yubihsm-go']
# atomex-me
# ['atomex-erc20-solidity', 'atomex-fa12-ligo', 'atomex-fa2-ligo', 'atomex-liquidity', 'atomex-michelson', 'atomex-nyx-ligo', 'atomex-solidity', 'atomex.bitcoinfees.scraper', 'atomex.client.core', 'atomex.client.desktop', 'atomex.client.web', 'atomex.client.wpf', 'atomex.imageservice', 'atomex.mobile']
# crypto-com
# ['aws-ne-sys', 'chain-desktop-wallet', 'chain-indexing', 'chain-tx-enclave', 'cosmos-rust', 'cosmos-sdk', 'cosmos-sdk-codeql', 'cro-staking', 'crypto-com.github.io', 'crypto-exchange', 'crypto-pay-magento2', 'crypto-pay-prestashop', 'curve25519-dalek', 'cxx', 'DeFi-Pulse-Adapters', 'defi-swap-swap-subgraph', 'defi-wallet-core-rs', 'deficonnect-monorepo', 'ed25519-dalek', 'elliptic-curves', 'hashes', 'ibc-solo-machine', 'incubator-teaclave', 'jellyfish-merkle-tree', 'kms', 'ledger-cosmos-go', 'ledger-crypto', 'ledger-crypto-rs', 'ledger-rs', 'libsecp256k1-rs', 'merkle_bit', 'pystarport', 'ring', 'rust-abci', 'rust-hpke', 'rust-secp256k1-zkp', 'sample-thaler-ios-example', 'sample-thaler-java-example', 'secp256k1-zkp', 'sgx-vendor', 'signatory', 'siwe-rs', 'swap-contracts-core', 'swap-contracts-periphery', 'swap-info', 'swap-interface', 'swap-subgraphs', 'swap-token-list', 'tendermint-rs', 'thaler', 'thaler-docs', 'thaler-ilp-settlement', 'thaler-indexing', 'thaler-multisig-demo', 'thaler-nodelib', 'thaler-sample-wallet', 'tmkms-light']
# ZunamiLab
# ['concordium.github.io', 'Testnet4-Challenges', 'translations-unofficial_ot4-c2', 'ZunamiProtocol', 'ZunamiUI']
# Aircoin-official
# ['AIR-Contract', 'AirCash', 'AirChain', 'AIRNFT', 'AirPay', 'AirPool', 'AirSwap', 'alpha-wallet-android', 'alpha-wallet-ios', 'arbitrum', 'assets', 'bips', 'Bogged-Token-List', 'Brand-Assets', 'DefiLlama-Adapters', 'Documments', 'Grants-Program', 'js-waku', 'matic.js', 'nim-waku', 'pancake-farm', 'pancake-swap-core', 'projects', 'snapshot', 'status-react', 'token-profile', 'tokens', 'v3-core']
# harvest-finance
# ['aip', 'harvest', 'harvest-api', 'harvest-front', 'harvest-landing', 'harvest-strategy', 'harvest-strategy-bsc', 'harvest-strategy-polygon', 'snapshot', 'tracing-efforts', 'vesting-info']
# ellipsis-finance
# ['ellipsis', 'ellipsis-audits', 'ellipsis-v2', 'factory-assets', 'pancake-swap-interface-v1', 'registry', 'stableswap-factory', 'v1-migration-snapshot', 'valas-lending-pool', 'vecrv-airdrop']
# lifinance
# ['contracts', 'customized-token-list', 'fuse-pool-zap', 'lifi-analytics-backend', 'lifi-analytics-dashboard', 'lifi-contract-types', 'lifi-web', 'lizard-token', 'nxtp-utils', 'paraswap-connext-sdk', 'pillar-lifi-zap', 'roadmap', 'sdk', 'sdk-node-sample', 'types', 'widget']
# polycatfi
# ['polycat-contracts', 'polycat-default-token-list']
# ovnstable
# ['balancer-v2-monorepo', 'cone-ui', 'DefiLlama-Adapters', 'frontend-v2', 'mStable-contracts', 'ovnstable-api', 'ovnstable-dapp', 'ovnstable-landing', 'ovnstable-pools', 'ovnstable-solana', 'ovnstable-widgets']
# balancednetwork
# ['app-icx', 'assets', 'balanced-backend-v2', 'balanced-contracts', 'balanced-exporter', 'balanced-java-contracts', 'balanced-js', 'balanced-network-info', 'balanced-network-interface', 'balanced-poc', 'BIP-info-list', 'docs', 'icons', 'roadmap', 'sdk-core', 'v1-sdk']
# everrise-ecosystem
# ['.github', 'assets', 'contracts-public', 'default-token-list', 'DeFi-Pulse-Adapters', 'DefiLlama-Adapters', 'eattheblocks', 'everrise-v3-contracts', 'EverStats', 'joe-tokenlists', 'nft-sales-adapters', 'spooky-info']
# Multiplier-Finance
# ['aave-protocol', 'MCL-FlashloanDemo', 'MCL-protocol-v2', 'MCL-SmartContracts', 'MultiSigWallet', 'openzeppelin-contracts', 'SmartContracts', 'snapshot-spaces', 'Tako-SmartContracts', 'Token-list', 'uniswap-v2-subgraph']
# scv-finance
# ['alpha-wallet-android', 'alpha-wallet-ios', 'portfolio', 'scvbot-collab']
# juster-finance
# ['juster-app', 'juster-core', 'juster-dipdup', 'juster-sdk', 'juster.fi', 'pytezos-harbinger-poster']
# dfyn
# ['assets', 'assets-1', 'banner-data', 'DeFi-Pulse-Adapters', 'dfyn-analytics', 'dfyn-exchange', 'dfyn-farms-info', 'dfyn-sdk', 'dfyn-token', 'dual-farm', 'flora-farms', 'new-host', 'prediction-market-data']
# gelatodigital
# ['aave-asset-listing', 'aave-protection-lib', 'aip', 'assets', 'auto-top-up', 'buffetBot', 'contract-proxy-kit', 'dca-sdk', 'default-token-list', 'DeFi-Pulse-Adapters', 'docs', 'dsa-connectors', 'dsa-sdk', 'dutchxUI', 'furu-limit-order-handler', 'g-uni-aave-oracle', 'g-uni-docs', 'g-uni-v1-core', 'gelato-chi', 'gelato-core-contracts', 'gelato-dca', 'gelato-instadapp-ui', 'gelato-network', 'gelato-omen', 'gelato-polywrap-template', 'gelato-subgraph', 'gelato-test-kit', 'gelato-tutorial', 'gelato-uniswap', 'gelato-user-proxy', 'gnosis-protocol-automations', 'hello-world', 'job-board', 'limit-orders-lib', 'metabox-sdk-hello-world', 'nxtp', 'omen-exchange', 'ops', 'ops-sdk', 'ops-sdk-hello-world', 'ops-twap-oracle', 'optimism', 'oracle-aggregator', 'pandao-contracts', 'price-aggregators', 'protocol-v2', 'range-orders-lib', 'relay-sdk', 'relay-sdk-hello-world', 'relay-sdks-monorepo', 'safe-modules', 'snapshot-strategies', 'sorbet-finance', 'swap-orders-lib', 'triggered', 'triggered-oz', 'wellTimed', 'yearn-saver']
# XY-Finance
# ['DefiLlama-Adapters', 'xy-finance-widget', 'xy-protocol']
# deversifi
# ['dvf-has-moved']
# kyberNetwork
# ['aggregator-subgraph', 'airdrop', 'api-docs', 'avax-trading-contest-reward-distribution', 'binance-client', 'blocks-subgraph', 'bridge_eos_smart_contracts', 'bridge_eth_smart_contracts', 'bsc', 'cclog', 'dao_sc', 'deribit-api', 'developer-portal', 'dgx-price-feeder', 'dmm-info', 'dmm-org', 'dmm-sdk', 'dmm-solana-interface', 'dmm-subgraph', 'docker-slate', 'dutchx-market-maker', 'elastic-subgraph', 'eos_smart_contracts', 'etheremon-wrapper', 'exchange-simulator', 'external-adapters-js', 'fosite', 'fpr-sdk.js', 'ftx-api', 'go-opera', 'go-project-template', 'hackathon-bounties', 'httpsign-utils', 'hydra', 'ieo-smart-contracts', 'jsonrpc2', 'katalyst_dao_sc', 'KIPs', 'ks-assets', 'ks-classic-sc', 'ks-sdk-classic', 'ks-sdk-core', 'ks-sdk-elastic', 'kyber-pro', 'kyber-tracker', 'KyberNetwork.github.io', 'KyberSwap', 'kyberswap-aggregator-sdk', 'kyberswap-error', 'kyberswap-interface', 'KyberSwap-iOS', 'KyberSwapElasticLM-Subgraph', 'KyberWidget', 'kyber_protocol_sc', 'kyber_reserves_sc', 'kyber_utils_sc', 'payment-widget-smart-contract', 'peace-relay', 'polygon-node-ansible', 'prometheus_bot_bin', 'promm-analytics', 'promm-sdk-go', 'py-reserve-sdk', 'quote-trade-analysis', 'redmine-roadmap-plugin', 'reserve-stats', 'ropsten-faucet', 'sanity-price-monitor', 'slackbot', 'smart-contracts', 'telegram-query-bot', 'TokenDistributionContracts', 'tokenrate', 'trading-contest-reward-distribution', 'tx-debugger', 'uniswap-sdk-core', 'uniswapv3-sdk', 'wallet-cache', 'webtail', 'widget-monitor-js', 'widget-monitor-php', 'widget-swift', 'widget-woocommerce', 'workflows-templates', 'workshop', 'zkyber-reward-distribution']
# metavaultorg
# ['charting-library-tutorial', 'DefiLlama-Adapters', 'metavault-contracts', 'metavault-interface', 'snapshot-spaces', 'trade-contracts', 'trade-interface', 'trade-leaderboard', 'trade-stats', 'trade-subgraph', 'yield-server']
# mstable
# ['aave-stake-v2', 'assets', 'DefiLlama-Adapters', 'earn-app', 'emissions-calculator', 'ethereum-lists', 'merkle-drop', 'MIPs', 'mStable-app', 'mStable-apps', 'mStable-components', 'mStable-contracts', 'mStable-dev-grants', 'mStable-docs', 'mStable-example', 'mStable-governance-app', 'mStable-governance-subgraph', 'mStable-landing', 'mStable-process-docs', 'mStable-QuestBook', 'mStable-staking-delegates', 'mStable-subgraph', 'mStable-subgraphs-monorepo', 'pooltogether-mstable']
# plotx
# ['LiquidityMining', 'plotx-v2-bug-tracking', 'smart-contracts', 'smart-contracts-L2', 'staking-L2', 'token-Polygon']
# renproject
# ['abi', 'aw', 'aw-rs', 'awt', 'bridge-v2', 'chaosdex', 'circleci-orbs', 'command-center', 'crypto-fees', 'darknode-cli', 'darknode-export', 'darknode-release', 'darknode-sol', 'econ-sim', 'enclave-testcase', 'frost', 'gateway-sol', 'gitcoin-bounties', 'hdwallet-go', 'hyperdrive', 'id', 'interoperability-examples', 'kv', 'libbtc-go', 'libeth-go', 'libzec-go', 'lightnode', 'mercury', 'mpc', 'mpc-rs', 'multichain', 'multichain-proxy', 'nodectl', 'pack', 'phi', 'ren', 'ren-client-docs', 'ren-js', 'ren-js-demo', 'ren-js-v3-demo', 'ren-js-v3-tutorial', 'ren-solidity-template', 'ren-substrate', 'ren-substrate-example', 'ren-tx', 'ren-ui', 'rencrypto', 'renevm', 'renjs-tutorial', 'renvm-explorer', 'renvm-subgraph', 'renvm-tracker', 'renxcs-go', 'rzl-mpc-specification', 'sample-go-app', 'secp256k1', 'secp256k1-go', 'secp256k1-rs', 'send-crypto', 'sentinel', 'shamir', 'shamir-rs', 'solana-ffi', 'statuspage-feed', 'surge', 'swapperd', 'swapperd-desktop', 'tokens', 'tx', 'wal', 'web-server-example']
# allbridge-io
# ['allbridge-master-contract', 'assets', 'bridge-assets', 'bridge-wrapped-token-evm-contract', 'DefiLlama-Adapters', 'ecosystem', 'joe-tokenlists', 'media', 'token-list']
# Uniswap
# ['actions', 'advanced-weth', 'api-deprecated', 'assets', 'convert-cidv0-cidv1', 'default-token-list', 'DeFi-Pulse-Adapters', 'deploy-v3', 'docs', 'ds-tools', 'fast-abi', 'governance', 'governance-seatbelt', 'hardhat-v3-deploy', 'info', 'info-redirects', 'interface', 'interface-redirects', 'jest-environment-hardhat', 'liquidity-staker', 'lp-action-contracts', 'mask-app', 'merkle-distributor', 'mrkl-drop-data-chunks', 'no-yolo-signatures', 'old-solidity-contracts', 'org-v1', 'polygon-bridge', 'redux-multicall', 'replace-vercel-dns-records', 'retroactive-query', 'returns-comparison-study', 'router-sdk', 'routing-api', 'sdk-core', 'smart-order-router', 'snapshot-gas-cost', 'solidity-lib', 'swap-router-contracts', 'sybil-interface', 'sybil-list', 'sybil-verifier-worker', 'token-list-bridge-utils', 'token-lists', 'tokenlists-org', 'unipig', 'unisocks', 'unisocks-erc20', 'unisocks-erc721', 'uniswap-first-contract-example', 'universe', 'v1-contracts', 'v1-docs', 'v1-interface', 'v1-sdk', 'v2-core', 'v2-periphery', 'v2-sdk', 'v2-subgraph', 'v3-core', 'v3-core-optimism', 'v3-info', 'v3-market-depth-study', 'v3-new-chain-deployments', 'v3-periphery', 'v3-periphery-optimism', 'v3-sdk', 'v3-staker', 'v3-subgraph', 'web3-react', 'widgets', 'widgets-demo']
# WaultFinance
# ['bnb-vault', 'busd-vault', 'busd-vault-strategy-venus', 'cake-vault', 'strategies', 'WAULT', 'WUSD']
# bifrost-platform
# ['AssetInfo', 'BIFI', 'BiFi-Bifrost-Extension-Contract', 'BiFi-staking-protocol', 'BiFi-X', 'BifrostHub', 'DeFi-Pulse-Adapters', 'DefiLlama-Adapters', 'ethereum', 'ETH_Emulation_Env', 'evm', 'flashloan-cooking', 'mev-geth-demo', 'RunnersScenario', 'wyvern-js', 'wyvern-schemas']
# niobfinance
# ['assets', 'niob', 'niob-ui']
# NemesisDao
# ['AngeL-Nodes', 'Contracts', 'Helena-Financial']
# ram-protocol
# ['abi', 'contract', 'DefiLlama-Adapters', 'ram-protocol.github.io', 'vfat-tools']
# elkfinance
# ['brand-assets', 'elkfinance.github.io', 'exchange-contracts', 'governance', 'graph-node', 'nginx-certbot', 'rewards', 'tokens']
# acorn-finance
# ['abi', 'contract']
# tomochain?q=luaswap
# []
# PRDTfinance
# ['contract']
# debridge-finance
# ['anchor', 'CoinGecko', 'debridge-contracts', 'debridge-contracts-v1', 'debridge-cross-chain-dapp-example', 'debridge-launcher', 'debridge-security', 'debridge-twap-oracle', 'denft', 'desdk', 'hardhat-debridge', 'node-monitoring', 'safe-transaction-service', 'solana-program-library', 'solana-tx-parser-public', 'test-send-method']
# typhoonnetwork
# ['typhoonnetwork.github.io']
# howeguo
# ['acn_smart_contract', 'AFBlurView', 'AFDropdownNotification', 'Alcatraz', 'amisdex', 'AMSmoothAlert', 'AppStore-Horizontal-Demo', 'ARNTransitionAnimator', 'ARNZoomImageTransition', 'ARSegmentPager', 'awesome-ios-ui', 'BackMenu', 'BadgeViewWithCustomImage', 'Bible-Assistant-master', 'blog', 'blog-1', 'BPForms', 'btc-rpc-explorer', 'bulma-templates', 'ChineseOrderAndSearchByPinyin', 'cnn-watermark-removal', 'ColorCube', 'CorePhotoBroswerVC', 'CSNotificationView-AFNetworking', 'CSNotificationViewBinding', 'CustomDynamicBlurNavigation', 'CYLExternalURL', 'demo-ui-ios', 'DeviceInfo', 'DGElasticPullToRefresh', 'DLPanableWebView', 'DLWidgetMenu', 'Documentation', 'DoubanFM', 'DraggableYoutubeFloatingVideo', 'DropdownMenu', 'DSLolita', 'DSTransparentNavigationBar', 'Dunk', 'DWBubbleMenuButton', 'EasyVideoRecorder', 'EIPs', 'erc20faucet', 'etherex', 'FDFullscreenPopGesture', 'FeSpinner', 'FileCompressor', 'firekylin', 'FSCalendar', 'gallery', 'GGTinypng', 'gitignore', 'GridStyleWebPhotoBrowser', 'gttc', 'GuillotineMenu', 'GYZCustomRefreshView', 'hexo-theme-hueman', 'howeguo.blog', 'howeguo.github.com', 'howeguo.github.io', 'HySideScrollingImagePicker', 'iBeacon', 'iex-multi-sender', 'IMDev-Android', 'IMDev-iOS', 'iOS-Custom-AlertView', 'iOS-Indoor-SDK', 'ios-material-design', 'iOS-Pro', 'ios-resource-3x2x1x', 'iOS-Runtime-Headers', 'iOSBlogCN', 'iOSStrongDemo', 'JazzHands', 'JDFPeekaboo', 'JKDBModel', 'JLNameSectionSort', 'JLWeChat-iPhone', 'JPNG', 'JTCalendar', 'JVFloatLabeledTextField', 'KKNavigationController', 'KRVideoPlayer', 'KSImageNamed-Xcode', 'KYGooeyMenu', 'KYJellyPullToRefresh', 'label-studio', 'LCActionSheet', 'leancloud-demos', 'ledger-app-eth', 'ledger-app-icx', 'maci', 'Menu', 'MHFacebookImageViewer', 'miksi-core', 'Monkey', 'moviedbapp', 'multisender', 'MWPhotoBrowser', 'nifty-wallet', 'node-xlsx-parser', 'NotificationChat', 'nsdata-zlib', 'NSDate-TimeAgo', 'Objective-C-Koans', 'OrderBook', 'PinterestAnimator', 'PKRevealController', 'PopMenu', 'ProgressHUD', 'protobuf-objc', 'Pull-to-Refresh.Rentals-iOS', 'PullToMakeSoup', 'pyhidapi', 'qiniu_upload', 'RLDTableViewSuite', 'RSKImageCropper', 'safe-contracts', 'SDCycleScrollView', 'SGActionView', 'shareblog', 'SlackTextViewController', 'solana-research-poc', 'stafi-bootstrap', 'STClock', 'SwipeableCellView', 'SWTableViewCell', 'SXNews', 'SYMaterialSegue', 'test-ghpages', 'test_howe', 'TKSwitcherCollection', 'TLAnimatedSegue', 'TLAttributedLabel', 'Token-BulkSender', 'token-profile', 'tornado-core', 'TQRichTextView', 'Tron_token_list', 'Tropos', 'TSMessages', 'TTCSDK_Android', 'TwitterCover', 'TwitterCover-1', 'TWMessageBarManager', 'TxSend-Sign-Demos', 'UIColor-HBVHarmonies', 'UICustomActionSheet', 'UINavigationItem-Loading', 'UUChatTableView', 'UUPhotoActionSheet', 'UzysAnimatedGifPullToRefresh', 'VCFloatingActionButton', 'VMGearsLoading', 'VVDocumenter-Xcode', 'wasmsnark', 'web3.js', 'WebViewJavascriptBridge', 'WeiBoActionSheetView', 'weui-wxss', 'WFCoretext', 'WKTableViewCell', 'WMPageController', 'WNXHuntForCity', 'www.thinkjs.org', 'XHScrollMenu', 'YLGIFImage', 'YUChineseSorting', 'ZYChat']
# NestedFinance
# []
# Pacoca-io
# ['assets', 'contracts', 'DefiLlama-Adapters', 'pacoca-pools-subgraph', 'utils', 'voting-power-subgraph']
# dexira
# ['assets', 'Bogged-Token-List', 'dexIRA', 'snapshot-spaces']
# portto
# ['alchemy-flow-contracts', 'aptos-core', 'aptos-go-sdk', 'assets', 'assets-staging', 'assets-v2', 'audaces-perps-ui', 'blocto-android-sdk', 'blocto-connector', 'blocto-dao-slugs', 'blocto-docs', 'blocto-flow-go-sdk', 'blocto-integration', 'blocto-ios-sdk', 'blocto-sdk', 'blocto-sdk-demo-app', 'blocto-solana-web3-provider', 'bloctobay-contracts', 'bloctoswap-contracts', 'blt-contracts', 'cadence', 'campaign', 'CocoaDebug', 'contenthash.kotlin', 'eslint-config-portto', 'ethereum-sign-util.kotlin', 'EthereumSignTypedDataUtil', 'evm-contract-wallet', 'fcl-demo', 'fcl-js', 'fcl-swift', 'flow', 'flow-dapp-demo', 'flow-hello-world', 'flow-jvm-sdk', 'flow-nft', 'flow-swift-sdk', 'flow-transactions', 'FSPagerView', 'ggr-demo', 'go-ethereum', 'go-tangerine', 'grpc-swift', 'Macaw', 'metamask-extension', 'QRCodeReader.swift', 'quiz', 'raydium-ui', 'react-responsive-carousel', 'redeem-code', 'redeem-voucher-contracts', 'restricted-nft', 'reward-demo', 'sdk-toolkit', 'secp256k1', 'secp256k1.swift', 'solana-contract-wallet', 'solana-go-sdk', 'solana-program-library', 'solana-web3-demo', 'solana-web3.kotlin', 'solana-web3.swift', 'sportsicon-contracts', 'SPStorkController', 'SVGKit', 'token-list', 'tweetnacl-swiftwrap', 'usdc-contracts', 'wallet-adapter', 'web3-react', 'web3.swift', 'web3modal']
# bamboo-defi
# ['bamboodefi-core', 'DefiLlama-Adapters', 'frontend', 'snapshot-spaces', 'token-list', 'vfat-tools']
# sportx-bet
# []
# WePiggy
# ['audits', 'contract_addresses', 'DeFi-Pulse-Adapters', 'DefiLlama-Adapters', 'Documents', 'multisigwallet', 'token-profile', 'vfat-tools', 'wepiggy-contracts', 'wepiggy-contracts-arbitrum', 'wepiggy-contracts-optimism', 'wepiggy.github.io']
# spin-fi
# ['near-defi-llama', 'near-dex-core-js', 'near-dex-node-js', 'spin-market-maker']
# fuseio
# ['3box-onboard', 'airnode', 'airnode-starter', 'alpha-wallet-android', 'alpha-wallet-ios', 'amb-bridge-subgraph', 'amb-transactions-table', 'amplitude-bigquery', 'app-ethereum', 'assets', 'base-x', 'blockscout-terraform', 'bridge-contracts-archived', 'bridge-monitor', 'bridge-oracle', 'bridge-subgraph', 'bridge-ui', 'canonical-weth', 'chainabstractionlayer', 'charge_wallet_sdk', 'contract-metadata', 'CountryCodePicker', 'cryptoassets', 'DAIPoints', 'dart-ethereum_address', 'default-token-list', 'deployment-bridge', 'deployment-playbooks', 'deployment-terraform', 'devops', 'dex-liquidity-provision', 'docs', 'earn-sdk', 'eth-block-tracker', 'ethereum-fuse-native-bridge-subgraphs', 'EZ-Flutter', 'FIPs', 'flutter-segment', 'flutter-zendesk', 'flutter_svg_provider', 'fuse-blocks-subgraph', 'fuse-bounties', 'fuse-bridge', 'fuse-cash-subgraph', 'fuse-dev-docs', 'fuse-dollar', 'fuse-explorer', 'fuse-funder', 'fuse-graph', 'fuse-inventory-manager', 'fuse-ipfs-proxy', 'fuse-l1', 'fuse-l2', 'fuse-lp-rewards', 'fuse-monitor', 'fuse-network', 'fuse-nft-contracts', 'fuse-nft-subgraph', 'fuse-staking', 'fuse-studio', 'fuse-studio-contracts', 'fuse-token-list', 'fuse-vesting-contracts', 'fuse-wallet', 'fuse-wallet-contracts', 'fuse-wallet-old', 'fuse-website', 'fuse.cash', 'fuseswap-default-token-list', 'fuseswap-info', 'fuseswap-interface', 'fuseswap-sdk', 'fuseswap-service', 'fuseswap-subgraph', 'Fuse_spark_test_script', 'graphprotocol-infrastructure', 'hdwallet-provider', 'interact', 'mnid_dart', 'monitoring-service', 'multi-rewards', 'nestat-node', 'nethermind', 'netstat-dashboard', 'node-walletconnect-bridge', 'notification-service', 'omnibridge-ui', 'onboard', 'optimism', 'pegswap-contracts', 'poa-chain-spec', 'poa-dapps-keys-generation', 'poa-dapps-validators', 'poa-dapps-voting', 'poa-network-consensus-contracts', 'poa-scripts-moc', 'poa-scripts-validator', 'pooltogether-contracts', 'projects', 'safe-contracts', 'safe-deployments', 'safe-infrastructure', 'safe-react', 'safe-transaction-service', 'solui', 'subscription-service', 'test-repo', 'tixlfinance-community-data', 'token-lists', 'tokenbridge', 'tokenbridge-contracts', 'tokenlist-assets', 'top-up-service', 'truffle', 'truffle-contract', 'truffle-core', 'truffle-default-builder', 'truffle-hdwallet-provider', 'uniswap-python', 'wallet', 'wallet-connect-dart', 'wallet-connect-flutter', 'wallet-connect-poc', 'walletconnect-monorepo', 'walletconnect-registry', 'wallet_core', 'wallet_sdk', 'web3-provider-engine', 'web3-react']
# byteball
# ['aa-channels-lib', 'aabot', 'aa_stats', 'accredited-investor-attestation', 'angular-carousel', 'angular-foundation', 'arbstore', 'arbstore_front', 'bank-aa', 'bitcointalk-attestation', 'bitz-orderbook-replication', 'bonded-stablecoin', 'bonded-stablecoin-buffer', 'bonded-stablecoin-referrals', 'bonded-stablecoin-ui', 'bot-example', 'btc-exchange', 'btc-oracle', 'buy-with-card', 'cascading-donations-backend', 'cascading-donations-ui', 'coinswap', 'conditional-token-sale', 'cordova-sqlite-plugin', 'counterstake-bridge', 'counterstake-bridge-ui', 'counterstake-demo-client', 'counterstake-governance-discord', 'counterstake-oracle', 'counterstake-sdk', 'counterstake-watchdog-discord', 'counterstats', 'cryptox-mm', 'developer-docs', 'discount-stablecoin-aa', 'discount-stablecoin-ui', 'draw-airdrop', 'email-attestation', 'flight-delays-insurance', 'flight-delays-oracle', 'getmein', 'github-attestation', 'go-byteballcore', 'governance_events', 'headless-obyte', 'ico-bot', 'liquidity-providers-distribution', 'luckybytes', 'nwjs-builder-phoenix', 'obyte-assets-ledger', 'obyte-browser-chat', 'obyte-cascading-donations', 'obyte-data-feed', 'obyte-exchange', 'obyte-explorer', 'obyte-explorer-frontend', 'obyte-faucet', 'obyte-gui-wallet', 'obyte-http-client', 'obyte-hub', 'obyte-media', 'obyte-merchant', 'obyte-qr-button', 'obyte-relay', 'obyte-stablecoin-v2-trigger-bot', 'obyte-statistics', 'obyte-web', 'obyte-witness', 'obyte-zeus', 'ocore', 'odds-maker-interface', 'odex-backend', 'odex-client', 'odex-client-browser', 'odex-frontend', 'odex-orderbook-replication', 'odex-orderbook-replication-browser', 'odex-passive-mm', 'odex-wallet', 'OIPs', 'oracle-example', 'oscript-editor', 'oscript-editor-backend', 'oscript-vscode-plugin', 'oswap-governance-discord', 'oswap-governance-ui', 'oswap-stats', 'oswap-stats-api', 'oswap-v2-aa', 'oswap-v2-sdk', 'pay-per-call-API', 'pay-per-call-demo', 'poll-bot', 'prediction-markets-aa', 'prediction-markets-backend', 'prediction-markets-ui', 'real-name-attestation', 'reddit-attestation', 'rpcify', 'sports-betting', 'sports-oracle', 'stable-oswap-arb', 'stable-oswap2-arb', 'stablecoin-icons', 'stablecoin-interest-arbitrage', 'stablecoin-t1-arbitrage', 'stablecoins-discord-bot', 'stablecoins-stats-api', 'steem-attestation', 'telegram-quiz', 'testnet-releases', 'token-registry-aa', 'token-registry-discord-bot', 'token-registry-ui', 'trading-tips', 'trading-tips-discord-bot', 'transition-web', 'unzip', 'upbit-orderbook-replication', 'username-attestation', 'WCG-distribution', 'zip']
# winery-land
# ['DEX', 'font-end', 'smart-contract-amm']
# nftkey
# ['nftkey-marketplace-v2']
# Leonicornswap
# ['api', 'exchangeAPI', 'LeonicornSwap-Token-Contract', 'SingleStaking']
# XWorldGames
# ['Dream-Card-V1', 'json-bignumber', 'nftds-resource', 'XWG-bsc-etl', 'XWG-contracts', 'XWG-docs', 'XWG-NFTds', 'XWG-token-contract', 'XWG-Website']
# yflink
# ['blog', 'burn', 'linkswap', 'LINKSWAP-info', 'LINKSWAP-rewards', 'linkswap-staking', 'LINKSWAP-v1-subgraph', 'memeteam', 'token-logos', 'wafflehouse', 'wns', 'YF-Link-Website', 'yflusd-frontend', 'yflusd-protocol', 'yieldfarming']
# theowlgame
# ['awesome', 'ecosystem', 'owl-core', 'owl-docs']
# NexusMutual
# ['blockchain-security-contacts', 'chain-data-api', 'cover-router', 'DeFi-Pulse-Adapters', 'dynamo-backup-to-s3', 'hugh_hack', 'incidents', 'iziToast-react', 'nexus-mutual-erc721-subgraph', 'quote-api', 'shield-mining', 'smart-contracts', 'snapshot-spaces', 'static-data', 'truffle-flattener', 'uniswap-lib', 'website']
# tapfantasy
# ['fantasyprotocol', 'token-list', 'tokens']
# akropolisio
# ['0x-launch-kit', '0x-launch-kit-frontend', '3rd-party-cookies-checker', 'active-strategy-framework', 'actix-rest', 'adel-swap-merkle-proofs', 'agent-forta', 'akropolis', 'akropolis-c2fc-srml', 'akropolis-ethereum', 'akropolis-frontend-assets', 'akropolis-mvp-v1.0', 'akropolis-mvp-v1.1', 'akropolis-network', 'akropolis-network-dapp', 'akropolis-sale', 'akropolis-subgraph', 'akropolis-vesting', 'akropolis-web', 'akropolis-website-v4', 'akropolisclient', 'AkropolisConnect', 'akropolisnetwork-frontend', 'AkropolisNFT', 'akropolisOS', 'akropolisOS-chain-node', 'AkropolisToken', 'alpha-vaults-contracts', 'aragon-apps', 'aragon-subgraph', 'aragon.js', 'astroport', 'awesome-uniswap-v3', 'balancer-exchange', 'blockpipe', 'bnbridge.exchange', 'bounty-server', 'brownie', 'brownie-strategy-mix', 'c2fc-cli', 'c2fc-registry', 'c2fc-specs', 'cairo-contracts', 'cairo-lang', 'cashflowrelay', 'cashflowrelay-poa-xdai', 'cashflowrelay-testnet', 'ChainX-Forked', 'chama-passport-apps', 'circleci-playground', 'cloudflare-cache-worker', 'cloudflare-manager', 'contracts', 'credit-pool-frontend', 'credit-pool-frontend-beta-defi', 'credit-pool-subgraph', 'curve25519-dalek', 'dao-kits', 'ddapptools', 'DeFi-Pulse-Adapters', 'defi-sdk', 'delphi', 'delphi-compensation-merkle-proofs', 'delphi-sandbox-frontend', 'dharma-chain', 'ed25519-dalek', 'erc20-substrate-bridge', 'eth-bridge-module', 'eth3-network', 'ethberlinzwei-hackaton', 'etherwallet', 'experimental', 'extension', 'flock', 'ganache-cli', 'gas-oracle', 'gitbook', 'gsn-v1-adapter', 'hackathon-frontend', 'kovan-endpoints', 'mai-protocol-v3', 'mailgun-sender', 'merlin', 'Multiownable', 'nest', 'nucypher-hackaton', 'oclif', 'openzeppelin-solidity', 'POC-polkadai-bridge', 'polkadot', 'polkadot-apps', 'polkahub-backend', 'polkahub-cli', 'polkahub-deployer', 'polkahub-frontend', 'polkahub-installer', 'polkahub-monorepo', 'pool-management', 'pytho', 'rand', 'relayer-kit', 'rewards-claiming-merkle-proofs', 'rust-libp2p', 'rust-web3', 'schnorrkel', 'snapshot-rinkeby-frontend', 'snapshot-spaces', 'snapshot.js', 'solidity-patterns', 'sparta', 'sparta-mainnet-frontend', 'sparta-testnet-frontend', 'staking-portal', 'starknet-bridge-subgraph', 'starknet.js', 'subgraph-status-action', 'substrate', 'substrate-api-client', 'substrate-bridge-module', 'substrate-ui', 'trust-ray', 'trust-wallet-android-source', 'trust-wallet-ios', 'TrustSDK-Android', 'turing-node', 'typechain-target-starknet', 'typechain-target-web3-rxjs', 'uniswap-v2-adapter', 'upgrades-safe-app', 'validator-bridge-module', 'vortex', 'Web3-collaboration', 'web3-frontend-starter-kit', 'web3-wallets-kit', 'web3.js', 'wiki', 'winterfell', 'wwwcashflowrelay', 'yearn-exporter', 'yearn-simulations', 'zos']
# gravis-finance
# ['Audit-RDAuditors-AutoFarming', 'chainbridge-solidity', 'chainbridge-utils', 'Evervoid-Buy-Fuel-for-GRVX', 'Evervoid-Contract-Mining-mission', 'Evervoid-contract-Referral-storage', 'Evervoid-Contract-Upgrade-Ships', 'Evervoid-Staking-ERC20', 'Evervoid-Staking-ERC721', 'Evervoid-Staking-GravisCollectible', 'frontend', 'Gmart-contract', 'GRVS', 'GRVX', 'Gswap-BigBang-Farming', 'Gswap-Farming', 'Gswap-Vampire', 'info', 'interface', 'metaCollectible', 'Pitch-Deck', 'sdk', 'subgraph', 'swap-core', 'swap-periphery', 't01-metadata', 'uikit']
# CafeSwap
# ['assets', 'bsc-farms-list', 'cafe-assets', 'Cafe-Migrate', 'cafe-swap-core', 'cafe-swap-periphery', 'CafeSwap-BuyBack-Vaults', 'CafeSwap-farm', 'CafeSwap-Pool_Staking', 'cafeswap-vaults', 'CafeSwap-Vaults-V2', 'CafeswapFarm_New', 'DefiLlama-Adapters', 'dex-api-v2', 'dex-info-api', 'DEX-V2', 'dual-farm-contracts', 'Farming-Poly-Contracts', 'farms-and-pools-list', 'farms-pools-list-polygon', 'mocha-token', 'snapshot-spaces']
# cexiswap
# ['cexiswap-audits', 'ecosystem']
# synthetixio
# ['blockchain-security-contacts', 'buidler', 'codegen-graph-ts', 'contract-linker', 'council-dilution', 'dapps-common', 'deprecated-whitepaper', 'docker-e2e', 'docker-node', 'docker-sec-tools', 'docker-shared', 'eslint-plugin-havven', 'eth-contract-metadata', 'ethereum-lists', 'fork', 'futures-keepers', 'gmv3-interface', 'governance-participation-snapshot', 'grants-synthetix-wrappers', 'hardhat-interact', 'issues', 'js', 'js-monorepo', 'js-template', 'kwenta', 'lambda-cloudwatch-slack', 'litepapers', 'next-optimized-images', 'NYBW-Hackathon-Gitcoin', 'optimistic-trader', 'optimized-images-loader', 'providers', 'roadmap', 'safe-app-synthetix-mintr', 'simulation', 'SIPs', 'SIPs-1', 'SIPs-Draft', 'sir-sccp-pr-interface', 'snapshot-spaces', 'snapshot-strategies', 'snapshot.js', 'snx-ambassadors-dapp', 'snx-grants-dao', 'snx-grants-dao-v2', 'snx-migrate', 'snx-partners-payout', 'snx-v3-prototype', 'solidifier', 'spartan-council', 'sprint-review', 'ssh-key-action', 'staking', 'stats', 'StructuredSmartContracts', 'susd-incentives-aave', 'synpress', 'synthetix', 'synthetix-assets', 'synthetix-dashboard', 'synthetix-data', 'synthetix-delegate', 'synthetix-docs', 'synthetix-exchange', 'synthetix-grants', 'synthetix-js', 'synthetix-mintr', 'synthetix-pm', 'synthetix-scripts', 'synthetix-shaula-frontend', 'synthetix-subgraph', 'synthetix-translations', 'synthetix-utility', 'synthetix-v3', 'synthetix-v3-labs', 'synthetix-website', 'synthetix-website-static-cms', 'thales-improvement-proposals', 'tokenvest', 'try-ethereum', 'ui', 'Unipool', 'uniswap-frontend', 'uniswap-v3-spot-twap-oracle', 'upload-s3-action', 'utility-contracts', 'v3gm-dapp', 'vanity-contract']
# liberofinancial
# ['assets', 'Bogged-Token-List', 'LiberoFinancial', 'tokens']
# AmbireTech
# ['adex-adview-manager', 'adex-brand', 'adex-careers', 'adex-constants', 'adex-explorer', 'adex-market', 'adex-models', 'adex-platform', 'adex-protocol', 'adex-protocol-cosmos', 'adex-protocol-eth', 'adex-protocol-substrate', 'adex-staking', 'adex-supermarket', 'adex-translations', 'adex-validator', 'adex-validator-stack-rust', 'adex_subgraph', 'ambire-brand', 'ambire-common', 'ambire-constants', 'assets', 'code4rena', 'cowprotocol-contracts-package', 'cowprotocol-services', 'cowswap-impl-1271', 'DefiLlama-Adapters', 'eip1271-fix-snapshot.js', 'eth-contract-metadata', 'ethers.js', 'evm-sigtools-public', 'ganache-core', 'immunefi-bounty', 'impl-1271-MyEtherWallet', 'is-eth-congested-website', 'MultiSigWallet', 'openzeppelin-contracts', 'signature-validator', 'snapshot-hub-1271-impl', 'snapshot-spaces', 'subgraph-v2', 'sushiswap-interface', 'sushiswap-sdk', 'tokens', 'tokens-info', 'uniswap-solidity', 'uniswap-token-list', 'wallet', 'wallet-dapp-catalog', 'wc-batch-transaction-aave', 'wc-batch-tx-aave-utilities', 'wc-batch-tx-implementation-pancakeswap', 'wc-send-batch-tx-aave-ui', 'wc-send-batch-tx-compound-frontend', 'wc-send-batch-tx-curve-dao', 'wc-send-batch-tx-quickswap-interface', 'wc-send-batch-tx-synthetix-dashboard', 'wc-send-batch-tx-uniswap-interface', 'wc-send-batch-tx-yearn-finance-v3', 'yearn-exporter']
# swaap-labs
# ['paraswap-dex-lib', 'swaap-core-v1', 'swaap-proxy-v1']
# WardenSwap
# ['DefiLlama-Adapters', 'warden-farm', 'warden-governance', 'warden-pool', 'warden-protocol']
# DoppleFinance
# ['assets', 'chains', 'DefiLlama-Adapters', 'DiamondHand', 'dopple-contract', 'Fractional-Synthetic', 'tokenlists', 'twindexswap-contract', 'Universal-USD']
# kalmar-io
# ['DefiLlama-Adapters', 'kalmar-assets', 'kalmar-bestrate', 'kalmar-bonding-contracts', 'kalmy-assets', 'leverage-yield-contracts', 'leverage-yield-contracts-busd', 'pancake-subgraph', 'uikit']
# Sakeswap
# ['bsc-testnet-blocks', 'sakeperp-arbitrageur', 'sakeperp-protocol', 'sakeswap-protocol']
# tendieswap
# ['ChunkyChickens-Contract', 'DefiLlama-Adapters', 'tendie-farm', 'TendieDEXContracts']
# autoshark-finance
# ['autoshark-contracts', 'autoshark-info-api', 'autoshark-subgraph-v1', 'DefiLlama-Adapters', 'dex-frontend', 'fins-periphery', 'pancake-toolkit', 'pancake-uikit', 'sdk']
# Standard-Hashrate-Group
# ['app.btcst.finance', 'assets', 'btcst.finance', 'btcst.github.io', 'MiningFarmWebApp', 'openzeppelin-upgrades', 'SmartContracts', 'snapshot', 'snapshot-spaces', 'standard-hashrate-group.github.io', 'swap.btcst.finance', 'v1.btcst.finance', 'vote.btcst.finance']
# inthenextversion
# ['audit-gravity-core-ctdsec', 'audit-gravity-core-obelisk', 'DefiLlama-Adapters', 'gravity-analytics-ui', 'gravity-core', 'gravity-subgraphs', 'studio']
# up-defi
# ['up-resource']
# FraxFinance
# ['aave-asset-listing', 'aip', 'apeswap-token-lists', 'assets', 'avalanche-bridge-resources', 'chaindata', 'compound-protocol', 'contract-metadata', 'frax', 'frax-langs', 'frax-oracle', 'frax-solidity', 'FraxFinance.github.io', 'fraxlend', 'fraxlend-audit', 'fraxswap-subgraph', 'merkle-airdrop-starter', 'paraswap-dex-lib', 'protocol-v2', 'snapshot-spaces', 'snapshot-strategies', 'snapshot.js', 'spiritswap-tokens-list-icon', 'token-list', 'tokens', 'uniswap-interface']
# OtterClam
# ['DefiLlama-Adapters', 'Massdiscordunban', 'otter-discordbot', 'otter-docs-gitbook', 'otter-frontend', 'otter-landing', 'otter-subgraph', 'otto-app', 'otto-subgraph', 'yield-server']
# oneswap
# ['contract_audit_report', 'oneswap_contract_ethereum', 'oneswap_contract_tron', 'oneswap_open_api', 'Uniswap-gas-test', 'uniswap_oneswap_arbitrage']
# HoneyFarmFi
# ['assets', 'DefiLlama-Adapters', 'HoneyFarmContracts', 'pancake-frontend']
# Switcheo
# ['assetlists', 'assets', 'awesome-switcheo', 'bsc-relayer', 'carbon-bootstrap', 'carbon-js-sdk', 'carbon-polynetwork-evm', 'carbon-polynetwork-n3', 'carbon-polynetwork-neo', 'carbon-polynetwork-zil', 'carbon-rpc-nodes', 'carbon-wallet-go', 'carbon-website', 'chain-registry', 'charting-wiki', 'code-challenge', 'cosmjs', 'cosmos-ledger', 'cosmos-poly-module', 'cosmos-relayer', 'cosmos-sdk', 'cryptometa', 'DefiLlama-Adapters', 'demex-bots', 'demex-website', 'dora', 'eth-relayer', 'gravity-bridge', 'hdwallet-provider', 'iavl', 'jazzicon', 'mnemonic-to-private-key', 'neo-relayer', 'NeoModules', 'ping-pub-explorer', 'poly', 'polynetwork-cosmos', 'polynetwork-signer', 'poly_toolbox', 'starport', 'switcheo-docs', 'switcheo-eth', 'switcheo-go', 'switcheo-js', 'switcheo-market-making-bot', 'switcheo-neo', 'switcheo-neo-token', 'switcheo-python', 'switcheo-token-neo3', 'switcheo-website', 'Switcheo.Net', 'tendermint', 'token-list', 'tradehub', 'tradehub-api-js', 'yield-server', 'zap-api', 'zilliqa-relayer', 'zilswap', 'zilswap-sdk', 'zilswap-token-list', 'zilswap-webapp', 'Zion', 'zwap-token']
# Weave-fi
# []
# thugs-defi
# ['bid-contract', 'liquidityhelper', 'marketplace', 'marketplace-contracts', 'snapshot', 'swap-api', 'swap-sdk', 'swap-subgraph', 'swap-token-list', 'thugs-contracts', 'traphouse-lib', 'use-wallet-bsc']
# hunnyfinance
# ['assets', 'DefiLlama-Adapters', 'ecosystem-projects', 'hunny', 'hunny-dao', 'hunnyswap', 'snapshot-spaces', 'tokens']
# 888tron
# ['contracts', 'ScatterApps', 'tronGamesClient']
# cheeseswapbsc
# ['api-docs', 'assets', 'assets-1', 'audit', 'b-cex', 'bsc', 'bsc-ecosystem', 'ChainBridge', 'cheese-nft', 'cheese-prod', 'cheese4dice-eip712', 'cheeseblock', 'cheesefinance-uitoolkit', 'cheesemaker', 'cheesenft-farm-ui', 'cheesenft-marketplace', 'cheesesubv2', 'cheeseswap-api', 'cheeseswap-core', 'cheeseswap-data-api', 'cheeseswap-info', 'cheeseswap-interface', 'cheeseswap-lib', 'cheeseswap-periphery', 'cheeseswap-sdk', 'cheeseswap2-lib', 'dice4cheese-state-channel', 'docs', 'free-money', 'gnosis-multisig', 'time-lock-wallet', 'tokens-info']
# KingLuigy
# ['KingSwap_Bridge_UI', 'KingSwap_L2', 'KingSwap_NFT', 'KingSwap_V1', 'KingSwap_V2', 'KingSwap_V3', 'NFT_Collectibles', 'uniswap-v2-periphery']
# babyswap
# ['assets', 'baby-swap-contract', 'tokens']
# ariesfinancial
# ['Aries-Financial', 'assets', 'Document', 'itoken', 'synthetix', 'yearn-subgraph']
# Bombmoney
# ['bitbomb-contracts', 'Bogged-Token-List', 'bomb-assets', 'bomb-contracts', 'bombfarm-api', 'bombfarm-collector', 'bombfarm-contracts', 'btc-stake', 'busm-frontend', 'farm-frontend', 'gitbook-docs', 'snapshot-spaces', 'use-wallet', 'venus-config', 'venus-protocol', 'venus-protocol-interface', 'ybomb-api', 'ybomb-assets', 'ybomb-meta', 'ybomb-sdk', 'yearn-finance-v3', 'zap']
# SecondLive
# ['contract', 'logo', 'SecondLiveMakerSDK']
# tomo-pool
# ['pools-tomowallet', 'tomopool-client', 'tomopool-contracts']
# mones-nfts
# ['mones-nfts', 'release', 'testnet']
# cometh-game
# ['cometh-assets', 'cometh-renting-contract', 'default-token-list', 'polygon-node-ansible', 'socketio-redis-adapter-demo', 'uniswap-v2-sdk']
# InfinityWallet
# ['aave-interface', 'apeswap-frontend', 'avax-ecosystem-projects', 'balancer-interface', 'bancor-interface', 'beefy-interface', 'BinanceChain-javascript-sdk', 'BinanceSmartChain-Blocks-Subgraph', 'Bitcoin.org', 'bitcoinjs-lib', 'blockbook', 'bsc-ecosystem', 'cronos-projects', 'Crypto-Assets', 'crypto-phishing-detector', 'docs-site', 'EVM-Chain-Balance-Checker', 'infinity-connector', 'Infinity-Core', 'Infinity-Periphery', 'InfinityCrypto-Languages', 'InfinityDonut', 'InfinityProtocol', 'InfinityProtocol-Rewards', 'InfinityProtocol-SDK', 'InfinityProtocol-Subgraph', 'nix-nim-waku', 'pancake-frontend', 'quickswap-interface-v2', 'rainbowkit', 'Releases', 'safe-react', 'safe-transaction-service', 'shard', 'Shard-Token', 'slips', 'snapshot', 'snapshot-spaces', 'snapshot.js', 'solana-wallet-adapter', 'sushiswap-interface', 'Synthetix-staking', 'Tokens-List', 'uniswap-interface', 'use-wallet', 'vfat-tools', 'wallet-address-validator', 'walletconnect-monorepo', 'walletconnect-registry', 'web3-onboard', 'web3-react', 'Web3Auth', 'web3modal', 'web3modal-vue', 'yearn-finance-interface', 'yieldfarming']
# polydex-fi
# ['celodex-vfat-tools', 'DefiLlama-Adapters', 'polydex-sdk', 'polydex-swap-core', 'polydex-swap-periphery', 'polydex-toolkit']
# cyclese96
# ['assets', 'chainbridge-solidity', 'corgib-marketplace', 'new-host', 'PolkaBridge-Contract', 'polkabridge-corgi', 'polkabridge-dapps', 'PolkaBridge-DEX', 'PolkaBridge-Farming', 'polkabridge-ino', 'polkabridge-insights', 'polkabridge-landingpage', 'polkabridge-launchpad', 'polkabridge-p2p', 'PolkaBridge-SDK', 'polkabridge-stake']
# wise-foundation
# ['liquid-nfts-audit', 'liquidnfts-audit-scope', 'wise-subgraph', 'wise-token-contracts', 'wise-token-contracts-bsc', 'wise-uniswap-interface', 'wise-website-requests', 'wiseswap']
# Steemhunt
# ['account-claimer', 'assets', 'audit-hunt', 'bootpay-ruby', 'browser-extension', 'clone-factory', 'DefiLlama-Adapters', 'dixel-contract', 'dixel-lottery', 'dixel-pixoo', 'dixel-v2-contract', 'eth-contract-metadata', 'gif-to-mp4-lamda', 'HUNT-ERC20', 'image-server', 'mailchecker', 'mint.club-contract', 'mint.club-sdk', 'mint.club-sdk-example', 'neverlose.money-contract', 'nomadtask-tutorial', 'otc-web', 'prerender', 'pricefeed', 'radiator', 'rainbowkit', 'react-phone-input-2', 'resource', 'reviewhunt-pre', 'ruby-eth', 'snapshot-spaces', 'steem', 'steem-docker', 'steem-ruby', 'steemapps-backend', 'steemapps-frontend', 'temporary-email-blacklist', 'testfly-tutorials', 'tvhunt-web', 'wallet-client', 'wallet-web', 'whitelist']
# jetfuelfinance
# ['assets', 'fortress-js', 'jetfuel-protocol', 'swap-token-list']
# tomochain
# ['apidocs', 'backups', 'blocktime-monitoring', 'bridgejs', 'bug-reports', 'cloud-images', 'coming-soon', 'coming-soon-01', 'crawlers', 'create-tomochain-masternode', 'crosschain-transfer-demo', 'devp2p-network', 'dex-deploy', 'dex-leaderboard', 'dex-protocol', 'dex-smart-contract', 'docs', 'e2e', 'erc20-crawler', 'errorpage', 'eth-net-intelligence-api', 'eth-phishing-detect', 'etherwallet', 'explorer', 'faucet', 'genesis-generator', 'gitbook', 'grafana-dashboard-tmpl', 'graph-node-tomochain', 'ico-contracts', 'infrastructure', 'ledger-app-eth', 'ledger-live-common', 'ledger-live-desktop', 'logos', 'luaswap-api', 'luaswap-core', 'luaswap-homepage', 'luaswap-info', 'luaswap-interface', 'luaswap-lite', 'luaswap-relayer', 'luaswap-sdk', 'luaswap-settlement', 'luaswap-snapshot', 'luaswap-snapshot-hub', 'luaswap-spaces', 'luaswap-stats', 'luaswap-subgraph', 'luaswap-token-list', 'maintenance', 'maintenance-luaswap', 'maintenance-v2', 'masternodes-droplets', 'masternodes-ec2', 'mm-bot', 'mongofluxd', 'multicall.js', 'MultiSigWallet', 'MyCrypto', 'netstats', 'open-certificate-demo', 'performance-test-bot', 'pm', 'privacy-docs', 'privacy-sc', 'privacy-wasm', 'privacyjs', 'proxy', 'relayers-info', 'rpc-swagger', 'slack-auto-invite', 'slate', 'slips', 'snapshot-score', 'snapshot.js', 'swagger-ui', 'testcases', 'testnet-runner-v2', 'tgelf', 'tmn', 'token-swap', 'tokens', 'tomo-filter-accounts-scripts', 'tomo-testnet-game', 'tomoapp.github.io', 'tomobridge', 'tomobridgev2', 'tomochain', 'tomochain-core-update-log', 'tomochain-local-runner', 'tomochain-node-healthcheck', 'tomochain-private-network', 'tomochain-quickstart', 'tomochain-rosetta-gateway', 'tomochain-testnet', 'tomochain-v1', 'tomochain-wp-theme', 'tomochain-wp-theme-v2', 'tomodex-landing-page', 'tomogate', 'tomoissuer', 'tomojs', 'Tomomask-extension', 'TomoMaskWeb', 'tomomaster', 'tomop', 'tomorelayer', 'tomoscan', 'tomostats', 'tomostatus', 'tomowallet', 'tomowallet-core-android', 'tomowallet-core-ios', 'tomowallet-web', 'tomowallet-web-testnet', 'tomox-droplets', 'tomox-launch-kit', 'tomox-market-maker', 'tomox-notification', 'tomox-quickstart', 'tomox-relayer-apis', 'tomox-relayer-fund-monitor', 'tomox-sdk', 'tomox-sdk-ui', 'tomox-stats', 'tomox-swagger', 'tomoxjs', 'trc20', 'trc21', 'trc721', 'trust-ray', 'trust-wallet-android', 'trust-wallet-ios', 'web3.js', 'wisepass-dapp']
# betSwirl
# ['circle-ecosystem', 'DefiLlama-Adapters', 'EPNS-backend', 'joe-tokenlists', 'Smart-Contracts', 'snapshot-spaces']
# peckshield
# ['EOS', 'eos_registration', 'go-ethereum', 'publications', 'vuln_disclosure']
# dypfinance
# ['Avalanche-Bridge-and-Farming-contracts', 'avax-bridge', 'AVAX-Farming-dApp', 'bsc-bridge', 'BSC-Farming-dApp', 'Buyback-Farm-Stake-Governance-V2', 'contract-security-audit', 'dyp', 'DYP-Bridge-and-Staking-on-Binance-Smart-Chain', 'dyp-circulating-supply', 'dyp-contracts', 'dyp-earn-vault', 'dyp-NFT', 'DYP-staking-governance-dapp', 'DYP-Website', 'ETH-Farming-dApp', 'gov', 'gov-avax', 'gov-bsc', 'launchpad', 'pancake-swap-interface', 'staking-governance-security-audits', 'Staking-Nft-Contract', 'token-lock-vesting-contracts', 'uniswap-info', 'uniswap-interface', 'Vault-dApp']
# locutusofborg111
# ['Add-Token', 'assets', 'borgswap', 'bsctokenlists-org', 'community-ideas', 'DefiLlama-Adapters', 'ferengivaults-bsc', 'ferengivaults-ftm', 'gatsby-pancake-api', 'klingftm', 'pancake-swap-interface', 'sevenofnine', 'snapshot-spaces', 'spock', 'swap-token-list', 'theborg', 'Token-BulkSender', 'token-multi-sender']
# ShibaNova
# ['Contracts', 'shibanova-swap-core', 'shibanova-swap-sdk-mainnet', 'shibanova-uikit', 'subgraph']
# MysteriumNetwork
# ['api', 'asymmetric-udp-echo', 'AVADO-DNP-Mysterium-Server', 'caddy-docker', 'code-sign-action', 'config', 'contracts', 'devbook', 'discovery', 'docs', 'documentation', 'dvpn-desktop', 'dvpn-desktop-tutorial', 'dvpn-web', 'electron-webpack', 'envsubst', 'ethcheck', 'ethdiff', 'EventBus', 'events', 'everssl', 'feedback', 'front-end-task', 'gdiplus', 'geth', 'go-ci', 'go-dvpn-web', 'go-ethereum', 'go-fileversion', 'go-openvpn', 'go-rest', 'go-virtualbox', 'go-wmi', 'go-wondershaper', 'gowinlog', 'gvisor', 'hyperv-myst-provision', 'iqp', 'js-tequilapi', 'labs-covid', 'logger', 'metrics', 'mips', 'mongobackup', 'myst-dappnode-pkg', 'myst-launcher', 'myst-launcher-osx', 'myst-telegram-bot', 'mysterium-checkbot', 'mysterium-vpn-desktop', 'mysterium-vpn-ios', 'mysterium-vpn-js', 'mysterium-vpn-mobile', 'MysteriumTests', 'nats.go', 'nightly', 'node', 'node-builds', 'node-js', 'node-supervisor', 'node-webui', 'node_infograph', 'openvpn-forwarder', 'openvpn3', 'payload-generator', 'payment-bindings', 'payments', 'payments-smart-contracts', 'pgbackup', 'pgpbackup', 'rewarder-smart-contracts', 'rollingwriter', 'screensavers', 'scylla-octopus', 'tequilapi-webapp-tutorial', 'terms', 'token', 'token-v2', 'vend', 'vmbackup', 'w32', 'walk', 'winter-is-coming', 'winter-server', 'wireguard-go', 'workshop', 'xgo', 'xgomobile']
# burgerswap-org
# ['burger-aggregator', 'burger-aggregator-subgraph', 'burger-switch-protocol', 'burgerswap-assets', 'burgerswap-core', 'burgerswap-subgraph', 'burgerswap-transit', 'graph-node']
# RabbitFinanceProtocol
# ['rabbit_dao', 'rabbit_finance_bsc']
# InterCroneworldOrg
# ['.github', 'defi-list', 'intercroneswap-interface', 'sdk-core', 'token-lists', 'v2-periphery', 'v2-sdk']
# onblockio
# ['avalanche-tokens-contracts', 'bsc-tokens-contracts', 'evm-gm-contracts', 'ghostmarket-sdk-js', 'n3-tokens-contracts', 'neo-devpack-dotnet', 'neo-modules', 'neo3-boa', 'NEP11TemplatePy', 'NEP11Workshop', 'phantasma-tokens-contracts', 'poly-bridge-frontend', 'polygon-tokens-contracts', 'proposals']
# bloXroute-Labs
# ['aiofluent', 'bdn-benchmarking', 'BEPs', 'bitcoin-unlimited-internal-gateway', 'bor', 'bsc', 'bxcommon', 'bxextensions', 'bxgateway', 'gateway', 'go-ethereum', 'metamask-extension', 'ontology', 'pyelliptic', 'pyrlp', 'quorum-maker', 'serum-client-go', 'serum-client-python', 'solana-go', 'solana-trader-proto', 'terraform-alicloud-vpc', 'terraform-aws-enforce-mfa', 'uvloop', 'west-wind-drift']
# delot-io
# ['assets', 'beta-testnet', 'bsc']
# refinableco
# ['assets', 'binance-hackathon-demo', 'coding-test-frontend-login-sign', 'coding-test-timelock-usage', 'controllers', 'dapps', 'jsdom-screenshot', 'metamask-mobile', 'node-ffprobe-installer', 'refinable-contract', 'refinable-sdk', 'reservoir-indexer', 'synpress', 'the-gallery', 'wallet-core', 'web3-react', 'web3-react-core']
# zenos-pavlakou
# ['crypto-multisender-smart-contract']
# CaskProtocol
# ['avalanche-ecosystem-projects', 'cask-contracts', 'cask-js-sdk', 'cask-protocol-subgraph', 'cask-webhook-bridge', 'lit-cask-example', 'lit-js-sdk', 'lit-protocol-docs', 'lit-share-modal-v3', 'snapshot-spaces']
# dungeonswap
# ['assets', 'DungeonSwap-contracts', 'misc', 'White-Paper']
# bitcoinHEX
# ['contract', 'logo', 'skeleton-ui', 'testui', 'tokenscript', 'UI2', 'wallet-utils', 'website']
# DoubleClub
# ['DefiLlama-Adapters', 'double']
# exon-center
# ['exon-nft', 'exon-swap', 'exon-token']
# cowswap
# ['assets', 'cow-dex', 'subgraph']
# ethalend
# ['Brand-Assets', 'Brandassets', 'etha-adapters', 'etha-protocol', 'Open-Grants-Program']
# AuraSwap-DEX
# ['assets', 'audit-report', 'smartcontract']
# xp-network
# ['application-editor-backend', 'assets', 'audits', 'aurora-grant-delivery', 'bridge-explorer', 'bridge-explorer-ui', 'bridge-interface', 'bridge-interface-bulkActions', 'bridge-ui-logics', 'bridge-widget', 'bsv-integration', 'claim-portal', 'contract-interfaces', 'DAVID', 'david_guilty', 'dfinity-grant-report', 'dfinity-integration', 'docs', 'documentation', 'egld-esdt-swap', 'elrond-api', 'elrond-bridge-docs', 'erc20-bridge-ui', 'ERC721A', 'estimator', 'ethereum-docker-dev-env', 'evm-asm', 'evm-contract-observer', 'exchange-rate', 'exchange-rate-backend', 'explorer-api', 'extension', 'fantom-grant-application', 'faucet-backend', 'faucet-ui', 'frost-dalek', 'frost-dalek-js', 'frost-secp256k1', 'frost-secp256k1-js', 'FT-bridge-relayer', 'gatechain-grant-application', 'gatechain-grant-delivery-report', 'gnosischain.world', 'godwoken-grant-delivery', 'grpc-web', 'Harmony-grant-delivery', 'hedera-grant-delivery', 'IoTeX-Grant-Delivery', 'live-website', 'mainnet-bridge-ui', 'metamask-extension', 'migration-module', 'migration-testsuite', 'move-compiler', 'near-grant-delivery', 'new-bridge-ui', 'new-wiki', 'nft-cache', 'nft-mint-ui', 'nft-parser', 'nft-transfer-ui', 'notifier-rest', 'observer-squad', 'ownerOf1155', 'poc-documentation', 'polkadot-freezer', 'polkadot-wraptoken', 'polkascan-explorer-gui', 'polkascan-os', 'polkascan-pre-explorer-api', 'polkascan-pre-harvester', 'pre-swap-claim-contract', 'private-repos-activity', 'rimble-ui', 'secret-network-grant-delivery', 'secret-xpnft', 'serde_xp_protocol', 'smartpy', 'solidity-compiler', 'staker', 'staking-contract-harvester', 'staking-portal', 'staking-ui', 'substrate-api-sidecar', 'supply-calculator', 'supportXpBot', 'telos-grant-application', 'testing-hedera', 'testing-secret_network', 'tezos-fa2-calls', 'ton-demo-m1', 'ton-grant-delivery', 'tonweb', 'ui-components', 'vechain-grant-application', 'Velas-Grant-Delivery', 'vm_hub_pallet', 'web3-erc20-contracts-types', 'website', 'whitelisted-api', 'xcmp_pallet-poc', 'XP-EOS-integration', 'xp-explorer', 'xp-near-integration', 'xp-rest', 'xp-the-open-network', 'xp-wallet', 'XP.network-HECO-Migration', 'xpBridgeDiscount', 'xpjs', 'xpjs-erc20', 'xpnet-blog', 'xpnet-js', 'xpnetwork-telegram-bot', 'xpnft-solana']
# NFTBlackMarket
# ['assets', 'tokens']
# PlaySmartGames
# []
# moonpotdev
# ['beefy-api', 'DefiLlama-Adapters', 'moonpot-app', 'moonpot-audits']
# chimpyswap
# ['chimpy-info-api', 'chimpy-profile-api', 'chimpy-swap-core', 'chimpyswap-sdk', 'chimpyswap-sdk-v2', 'chimpyswap-uikit', 'smartContracts', 'tokens-lists']
# ecency
# ['apps', 'auto-delegator', 'awesome', 'awesome-hive', 'busy', 'cf-cache', 'create-account', 'delegation-check', 'dhive', 'dhive-test', 'ecency-mobile', 'ecency-vision', 'esi', 'esteem', 'esteem-desktop', 'esteem-lib', 'esteem-monitor', 'esteem-surfer', 'esteem-university', 'esteem.app', 'estmto', 'esync', 'golosuy', 'hbd-return', 'hive2elastic', 'hiveapi', 'hivemind', 'hivescript', 'hivesearcher', 'hivesigner-api', 'hivesigner-sdk', 'hivesigner-tests', 'hivesigner-ui', 'iconv-lite', 'image-proxy', 'lineman', 'media-kit', 'pick', 'react-native', 'react-native-actionsheet', 'react-native-autocomplete-input', 'react-native-code-push', 'react-native-datepicker', 'react-native-modal-dropdown', 'react-native-modal-popover', 'react-native-multi-slider', 'react-native-receive-sharing-intent', 'react-native-render-html', 'React-Native-Scale-Slider', 'react-native-scrollable-tab-view', 'react-native-slider', 'react-native-swiper', 'react-native-tags', 'render-helper', 'rpc-proxy', 'steem-js', 'steemapi', 'steemauth', 'steemjsapi', 'steemlookup', 'steemmonitor', 'steempoll', 'vision-api', 'xapi']
# SiberianSwap-Finance
# ['Audits', 'Siberianswap-contract', 'vfat-tools', 'vfat-tools-1']
# RedChillies-Core
# ['Contracts', 'cryptometa', 'Public-Contracts', 'RedChillies-Assets', 'RedChillies-IP', 'RedChillies-Token', 'tokens', 'zap-api', 'ZilChill-assets', 'Zilliqa-Merkle-Tree-Generator']
# PolyQuity
# ['assets', 'audits', 'contracts', 'default-token-list', 'DefiLlama-Adapters', 'defillama-server', 'stabilize_airdrop_list']
# CashCowProject
# ['assets', 'cashcow-contracts', 'cashcow-frontend', 'cashcow-uikit']
# BlockTimeWorld
# ['assets', 'crawler', 'cryptic', 'EVMBridge', 'identicon-api', 'learnmatic', 'LiquidityCrawler', 'matic-pos-bridge', 'matix', 'memes', 'mutants-v1', 'new-host', 'pos-plasma-tutorial', 'snapshot-spaces', 'staking-boss', 'SWAM-Token', 'swapman', 'SwapMatic', 'uniswap-api', 'uniswap-v1', 'uniswap-v1-interface', 'waifus']
# HenLisa
# ['token-list']
# bourbondefi
# ['anchor-web-app', 'bourbon-api', 'bourbon-contracts', 'bourbon-contracts-incubator', 'bourbon-frontend-amm', 'bourbon-frontend-farms', 'Bourbon-frontend-farms2', 'bourbon-frontend-farms3', 'Bourbon-milky-sdk', 'Bourbon-sdx-exchange', 'bourbon-sdx-sdk', 'bourbon-toolkit', 'bourbon-uikit', 'bourbondao-frontend', 'bourbondefi-sdk', 'BourbonV2-frontend-amm', 'BourbonV2-frontend-farms', 'BourbonV2-uikit', 'CakeEater-contracts', 'CakeEater-farm-frontend', 'CakeEater-frontend', 'CakeEaterFarm-contracts', 'Captainsfarm-uikit', 'dogechain-sdk', 'dogechain-uikit', 'eth-anchor-contracts', 'example_nft_minter', 'frontend_base_dapp', 'gatsby-bourbon-api', 'generative-art-opensource', 'lottery-contract', 'luckycat-auto-feeder', 'LuckyCat-Predict-Frontend', 'luckycatbnb-contract', 'MilkBourbon-uikit', 'nerdy_coder_clones_tutorial', 'olympus-contracts', 'openzeppelin-contracts-upgradeable', 'polycat-contracts', 'pythia-subgraph', 'pythia-uikit', 'SugarRush-uikit', 'tombfinance-contracts', 'tombfinance-frontend', 'VaulTec-Frontend', 'WhiskeyDAO-contracts', 'WhiskeyDAO-frontend']
# steem-engine-exchange
# []
# whale-swap
# ['audits', 'DefiLlama-Adapters', 'vfat-tools', 'whaleswap-core', 'yield-server']
# Xpool-lab
# ['assets', 'protocol', 'protocol-subgraph', 'resources', 'xpo-token-v1']
# valuedefi
# ['audit', 'DeFi-Pulse-Adapters', 'DefiLlama-Adapters', 'ethereum-lists', 'fbh-smartcontracts', 'firebird-smartcontracts', 'snapshot-spaces', 'trustwallet-assets', 'value-iou', 'valuebsc-subgraph', 'valuedefi-docs', 'valueliquid-core', 'valueliquid-subgraph', 'vaults', 'vsafe-contracts']
# VeneraFinance
# ['Documents', 'Info-Analytics', 'VeneraSwap-Frontend', 'VeneraSwap-Interface', 'veneraswap-subgraph']
# latteswap-official
# ['assets', 'cypress-metamask', 'default-token-list', 'DefiLlama-Adapters', 'flat-contract', 'icons', 'latteswap-config', 'latteswap-contract', 'latteswap-open-api', 'survival-game-contract', 'synpress']
# timeleapfinance
# ['DefiLlama-Adapters', 'Docs-Whitepapers', 'timeleap-contracts', 'timeleap-industries-static-site', 'timeleap-uikit', 'vfat-tools']
# actifit
# ['actifit', 'actifit-bot', 'actifit-defi-contracts', 'actifit-defi-frontend', 'actifit-defi-frontend-amm', 'actifit-defi-frontend-farms', 'actifit-defi-uikit', 'actifit-ios', 'actifit-landingpage', 'actifit-toolkit', 'tokensale']
# cougarswap
# ['beamswap-tokenlist', 'CGX', 'cougar-audits', 'cougar-contracts', 'cronos-awesome', 'Cronos_Contract', 'DefiLlama-Adapters', 'HarmonyCougar', 'PolyCougar_Contract', 'vfat-tools']
# easyswap-team
# ['app.easyswap.finance', 'aragon-apps', 'aragon-cli', 'client', 'dao-templates', 'easyswap_contracts', 'uniswap-v2-core', 'uniswap-v2-periphery', 'uniswap-v2-sdk']
# chirenonhive
# ['Entity', 'obs-studio', 'VimmTV']
# tsladoge
# ['assets', 'tsladoge.github.io']
# ustx
# ['realnft', 'ustx-dex']
# decentraland
# ['account', 'actions', 'add-mana', 'adr', 'agora', 'aragonswap', 'archipelago', 'archipelago-service', 'architecture', 'atlas-server', 'auction', 'auth-go', 'automated-webgl-test', 'aux-contracts', 'avatar-asset-test-tool', 'avatar-assets', 'avatars-contract', 'base-ts-project', 'bid-contract', 'bounties', 'bronzeage-editor', 'bronzeage-node', 'builder', 'builder-assets', 'builder-client', 'builder-server', 'calculate-populated-land', 'canilla', 'catalyst', 'catalyst-api-specs', 'catalyst-client', 'catalyst-commons', 'catalyst-comms-peer', 'catalyst-contracts', 'catalyst-monitor', 'catalyst-node-commons', 'catalyst-owner', 'catalyst-scripts', 'catalyst-stats', 'catalyst-stats-aggregator', 'catalyst-storage', 'cli', 'cli-e2e', 'cli-preview-in-server', 'collection-proxy-verifier', 'collections-graph', 'com.decentraland.unity-renderer', 'com.decentraland.unity-renderer-test', 'common-contracts', 'common-schemas', 'comms-v3', 'comms3-livekit-transport', 'comms3-transports', 'communications-protocol', 'communications-server', 'content-hash-tree', 'content-service', 'content-validator', 'contracts', 'contracts-plugins', 'crdt', 'crdt-scene', 'dao-apps', 'dao-curations-calc', 'dapp-boilerplate', 'dappeteer', 'dapps-issues', 'dcl-access-area', 'dcl-builder-hud', 'dcl-deploy-action', 'dcl-ecs-quests', 'dcl-gin', 'dcl-quests-api-spec', 'dcl-scene-writer', 'dcl-sprites', 'dcl-tslint-config-standard', 'dcl-viper', 'dcl-voice', 'dcl-xml', 'DCLVideoPlayer', 'DCLVideoPlayerUnity', 'debug-comms', 'decentraform', 'decentraland-auth', 'decentraland-builder-scripts', 'decentraland-claim-app', 'decentraland-commons', 'decentraland-connect', 'decentraland-crypto', 'decentraland-crypto-fetch', 'decentraland-crypto-middleware', 'decentraland-crypto-utils', 'decentraland-dapps', 'decentraland-ecs-utils', 'decentraland-eth', 'decentraland-experiments', 'decentraland-gatsby', 'decentraland-gatsby-deploy', 'decentraland-l2-utils', 'decentraland-lists-graph', 'decentraland-noise-utils', 'decentraland-npc-utils', 'decentraland-rpc', 'decentraland-server', 'decentraland-transactions', 'decentraland-ui-utils', 'DecentralandUnityPlugin', 'deeplink-landing', 'deployment-map', 'deployments-to-sqs', 'districts', 'documentation', 'documentation-cn', 'documentation-creators', 'documentation-kr', 'dservices', 'dummy-token', 'ecs', 'ecs-math', 'ecs-reference', 'ecs-types', 'ecs7-template', 'editor-legacy', 'ephemeralkey', 'erc721', 'es5-context', 'eslint-config', 'eth-connect', 'eth-health', 'eth-sig-util', 'ethalarm', 'ethereum-blocks', 'ethereumjs-util', 'events', 'explorer', 'explorer-bff', 'explorer-desktop', 'explorer-desktop-launcher', 'explorer-technical-backlog', 'explorer-website', 'fashion-week', 'ffmpeg-static', 'FFMPEGMediaDecoder', 'frontend-starter', 'gate', 'gh-action-release', 'gltf-pipeline', 'governance', 'graph-node', 'hashing', 'hexutil', 'ion-sdk-js', 'ion-sfu', 'ipfs-node', 'isomorphic-form-data', 'issues', 'jekyll-feed', 'jekyll-json-feed', 'js-sdk-toolchain', 'kernel', 'kernel-interface', 'kernel-legacy', 'l2-airdrop', 'lambdos', 'land', 'land-auction', 'land-balance-register', 'LAND-permissions-graph', 'landing-festival', 'ledger-wallet-provider', 'lighthouse', 'lighthouse-service', 'linker-dapp', 'livekit-adapter', 'mana', 'MANA-community-fund-learning-content', 'mana-graph', 'manaboard', 'marketplace', 'marketplace-contracts', 'marketplace-legacy', 'matrix-client', 'matrix-playbook', 'matrix-reloaded', 'monaco-typescript', 'MultiSigWallet', 'nats-test', 'new-rpc', 'nft-schema', 'nft-server', 'nft_bazl', 'nifty-gg', 'node-runtime', 'opscli', 'pass-through', 'peerjs-server', 'pixel-chain-mural-scene', 'player-documentation', 'plaza-asian', 'plaza-genesis', 'poap-ui', 'portable-experience-sample', 'posix', 'pow-authorization-server', 'proposals', 'protoc-gen-csharp', 'protoc-gen-dcl', 'protocol', 'provider-engine', 'rca', 'redux-persistence', 'redux-persistence-engine-localstorage', 'renderer-protocol', 'rendezvous', 'rentals-contract', 'ren ...
# axieinfinity
# ['clap-nested', 'cloud-storage-rs', 'festival', 'game-test-02', 'infura-exporter', 'jenkins-library', 'mav', 'mixer-playground', 'mixer-unity', 'public-scripts', 'public-smart-contracts', 'puff-discord-bot', 'ronin-netstats', 'ronin-smart-contracts', 'ronin-snapshot', 'spine-rs', 'steit', 'truffle-deploy', 'w3b']
# loomnetwork
# ['ansible-nomad', 'apig', 'apps', 'auth0.net', 'blockatlas', 'blockscout', 'browser-solc', 'cocos-sdk', 'cryptozombie-lessons', 'cryptozombies-lesson-code', 'dashboard', 'dc-translations', 'delegation-api-docs', 'e2e', 'erc721x', 'eth-cli', 'eth-contract-metadata', 'ethcontract', 'EthDeploy', 'ethdeploy-client', 'Etherboy', 'etherboy-core', 'etherwallet', 'ez-gin-template', 'fresh', 'gamechain', 'go-ecdh', 'go-ethereum', 'go-loom', 'go-plugin', 'go-pubsub', 'go-solidity-sha3', 'go-transfer-gateway', 'hexo-deployer-s3', 'hexo-renderer-scss', 'hid', 'homebrew-client', 'iavl', 'learnxinyminutes-docs', 'ledger-wallet-provider', 'life', 'limiter', 'loom-cli', 'loom-examples', 'loom-identity-js', 'loom-js', 'loom-js-samples', 'loom-playbooks', 'loom-provider-json-rpc-proxy', 'loom-sdk-documentation', 'loom-token', 'loom-truffle-provider', 'loom-unity-project-template', 'loomchain', 'mamamerkle', 'mavonEditor', 'mycrypto.com', 'Nethereum', 'node-sass-magic-importer', 'Node.js-prototype', 'nomad', 'oauth2-noserver', 'oembed', 'phaser-sdk-demo', 'pkcs11', 'plasma-cash', 'plasma-cli', 'plasma-indexer', 'plasma-paper', 'rollout_ui2', 'solidity-social-example', 'solidity-transfer-gateway', 'soliditycookbook.com', 'solidityx-js', 'solidityx.org', 'Spoon-Knife', 'spores', 'substrate', 'tendermint', 'testrpc', 'tiles-chain', 'tiles-chain-evm', 'TimeLock', 'token-gateway-example', 'tokens', 'tokens-1', 'transfer-gateway-example', 'truffle-dappchain-example', 'truffle-hdwallet-provider', 'truffle-loom-builder', 'trust-ray', 'trustwallet-assets', 'trustwallet-web-core', 'unity-evm-blackjack', 'unity-sdk', 'unity-sdk-docs', 'unity-tiles-chain', 'unity-tiles-chain-evm', 'unity3d-identity', 'vault', 'vt9nx', 'vue-block-explorer', 'vue-editor', 'vue-monaco-editor', 'vue-multianalytics', 'wallet-core', 'walletconnect-monorepo', 'weave-blueprint', 'yubihsm-go', 'zb_game_mode', 'zombie-battleground-api', 'zombie-char-component']
# idexio
# ['DeFi-Pulse-Adapters', 'DefiLlama-Adapters', 'hummingbot', 'hummingbot-dev', 'idex-contracts-earnings-escrow', 'idex-contracts-silverton', 'idex-contracts-whistler', 'idex-farm', 'idex-farm-v2', 'idex-sdk-js', 'IDEXd', 'investigations', 'smart-contract-registry', 'staking-replicator']

# %%
print(json_object)
# Out:
# {
#     "id": "ArrakisFinance",
#     "location": null,
#     "contributors": [
#         [
#             "Mr-Madila",
#             null
#         ],
#         [
#             "shankinson",
#             "Halifax, NS"
#         ],
#         [
#             "singingtori",
#             null
#         ],
#         [
#             "0xJessica",
#             "Arrakis"
#         ],
#         [
#             "ittikorns",
#             "Dubai, United Arab Emirates"
#         ],
#         [
#             "0mkara",
#             "Arrakis"
#         ],
#         [
#             "kassandraoftroy",
#             null
#         ],
#         [
#             "RedVeil",
#             null
#         ],
#         [
#             "cyberrothschildi",
#             null
#         ],
#         [
#             "0xChani",
#             "Arrakis"
#         ],
#         [
#             "monet-supply",
#             null
#         ],
#         [
#             "stephenenglish",
#             null
#         ]
#     ]
# }
